# %% [markdown]
# # Pull Gridmet data to look at correlation
# ## Variables to compare with physics-based model:
# - PDSI
# - Elevation
#
# From https://climatedataguide.ucar.edu/climate-data/palmer-drought-severity-index-pdsi#:~:text=The%20Palmer%20Drought%20Severity%20Index,more%20extreme%20values%20are%20possible.
#
# The Palmer Drought Severity Index (PDSI) uses readily available temperature and precipitation data to estimate relative dryness. It is a standardized index that generally spans -10 (dry) to +10 (wet). Maps of operational agencies like NOAA typically show a range of -4 to +4, but more extreme values are possible.
#
# ### Environment -- use 'ofp_for_te.yml'
# Base anaconda installation, conda env update with ofp_env_upd.yml (from onhm-fetcher parser Github, added pyviz)

# %% [markdown]
# ## Setup

# %%
# step 0- Import the needed packages
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

import geopandas as gpd
import xarray as xr
#import contextily as ctx
import pandas as pd
import os
import numpy as np
from shapely.geometry import Point, polygon
from matplotlib.backends.backend_pdf import PdfPages
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\galanter\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['var']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# step 1- set up directory, plot the TE locations, set up a geopandas dataframe and add columns for the netcdf data
TEdir = r'C:\WBEEP\Thermoelectric-master\Climate_data_fetcher'
TE_df = gpd.read_file(os.path.join(TEdir, '..\GIS','2015_TE_Model_Estimates_lat.long_COMIDs.shp'))
TE_df.reset_index(drop = True, inplace =True)
TE_df = TE_df[TE_df.STATE !='HI']
TE_df = TE_df[TE_df.STATE !='AK']

#get list of plants and change 'NTC/MCRD' name for loop to get data at each point
lst_of_plants = TE_df.loc[:,'PLANT_NAME']
lst_of_plants.update(pd.Series(['NTC_MCRD_Energy_Facility'], index =[737]))

# %%
len(lst_of_plants)
# Out:
# 1106

# %%
# for testing purposes since loop of 1122 plants takes a while! Uncomment these if you want to go test something out

#lst_of_plants = lst_of_plants[0:5]
#lst_of_plants

# %%
input_2015 = pd.read_csv(os.path.join(TEdir, '..\TE_Harris_Diehl_2015', '2015_TE_input_data_AEG.csv'))

# %%
input_2015.head()
# Out:
#    EIA_PLANT_ID     PLANT_NAME  COUNTY STATE NAME_OF_WATER_SOURCE  \
# 0             3          Barry  Mobile    AL         Mobile River
# 1             3          Barry  Mobile    AL         Mobile River
# 2             7        Gadsden  Etowah    AL          Coosa River
# 3             8         Gorgas  Walker    AL        Warrior River
# 4            10  Greene County  Greene    AL  Black Warrior River
#
#          COOLING_TYPE           MODEL_TYPE  PERCENT_CD_ALLOCATION  \
# 0             COMPLEX   ONCE-THROUGH RIVER                    100
# 1             COMPLEX  RECIRCULATING TOWER                    100
# 2  ONCE-THROUGH FRESH   ONCE-THROUGH RIVER                    100
# 3  ONCE-THROUGH FRESH   ONCE-THROUGH RIVER                    100
# 4  ONCE-THROUGH FRESH   ONCE-THROUGH RIVER                    100
#
#    ELEVATION_FT  POND_AREA  ... EV_03 EV_04 EV_05 EV_06 EV_07 EV_08 EV_09  \
# 0          15.0  1000000.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1          15.0  1000000.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2         535.0  1000000.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3         275.0  1000000.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4         100.0  1000000.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#   EV_10 EV_11 EV_12
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 84 columns]

# %%
conv_ft_mtr = 0.3048
input_2015['ELEVATION_MTR'] = input_2015['ELEVATION_FT']*conv_ft_mtr

# %%
elev_phys_mod = input_2015[['EIA_PLANT_ID','ELEVATION_MTR', 'STATE']]
elev_phys_mod = elev_phys_mod.drop_duplicates(subset = 'EIA_PLANT_ID')
# Exclude AK and HI
elev_phys_mod = elev_phys_mod[elev_phys_mod.STATE !='AK']
elev_phys_mod = elev_phys_mod[elev_phys_mod.STATE !='HI']

# %%
len(elev_phys_mod)
# Out:
# 1106

# %%
# step 1- pull elevation from gridMET, units in meters *** or just pull in csv already ran 
#var = 'elev/elev'
dh= 'elevation'
dirPath='http://thredds.northwestknowledge.net:8080'

fileName = '/thredds/dodsC/MET/elev/metdata_elevationdata.nc'
fullfilename= dirPath+fileName
print(fullfilename)
ds = xr.open_dataset(fullfilename)
print(ds, flush =True)

lathandle=ds['lat']
lonhandle=ds['lon']
timehandle=ds['day']
datahandle = ds[dh]
#crshandle=ds['crs']
ts = datahandle.sizes
print(type(ts), flush=True)
print(ts['day'], flush=True)
dayshape = ts['day']
Lonshape = ts['lon']
Latshape = ts['lat']

for i, plant in enumerate(lst_of_plants):
    var = (ds[dh])
    var1 = var.interp(lat =TE_df.iloc[i,5] , lon = TE_df.iloc[i,6])
    var_df = xr.DataArray.to_dataframe(var1)
    var_df = var_df.drop(['lat', 'lon'], axis = 1)   
    
    
    var_df['PLANT_NAME'] = plant 
    var_df['EIA_PLANT_ID'] = TE_df.iloc[i,0]  
    
    if i == 0:
        plants_df = var_df.copy(deep=True)
    else:
        plants_df = plants_df.append(var_df)
        
    print("plant # " + str(i) + " out of 1122 " + "plant name = " + plant)
# Out:
# http://thredds.northwestknowledge.net:8080/thredds/dodsC/MET/elev/metdata_elevationdata.nc
# <xarray.Dataset>
# Dimensions:    (day: 1, lat: 585, lon: 1386)
# Coordinates:
#   * lon        (lon) float32 -124.77216 -124.7305 ... -67.10641 -67.064735
#   * lat        (lat) float32 49.396023 49.354355 49.31269 ... 25.104736 25.06307
#   * day        (day) datetime64[ns] 1900-01-02
# Data variables:
#     elevation  (day, lat, lon) float32 ...
# Attributes:
#     author:   John Abatzoglou - University of Idaho, jabatzoglou@uidaho.edu
#     date:     14 November 2011
#     note1:    The projection information for this file is: GCS WGS 1984.
#     note2:    Citation: Abatzoglou, J.T., 2012, Development of gridded surfac...
# <class 'xarray.core.utils.Frozen'>
# 1
# plant # 0 out of 1122 plant name = Barry
# plant # 1 out of 1122 plant name = Gadsden
# plant # 2 out of 1122 plant name = Gorgas
# plant # 3 out of 1122 plant name = Greene County
# plant # 4 out of 1122 plant name = E C Gaston
# plant # 5 out of 1122 plant name = Browns Ferry
# plant # 6 out of 1122 plant name = Colbert
# plant # 7 out of 1122 plant name = Widows Creek
# plant # 8 out of 1122 plant name = Dolet Hills
# plant # 9 out of 1122 plant name = Charles R Lowman
# plant # 10 out of 1122 plant name = Platte
# plant # 11 out of 1122 plant name = Whelan Energy Center
# plant # 12 out of 1122 plant name = Escalante
# plant # 13 out of 1122 plant name = Holcomb
# plant # 14 out of 1122 plant name = Cholla
# plant # 15 out of 1122 plant name = Ocotillo
# plant # 16 out of 1122 plant name = West Phoenix
# plant # 17 out of 1122 plant name = Yucca
# plant # 18 out of 1122 plant name = H Wilson Sundt Generating Station
# plant # 19 out of 1122 plant name = Oklaunion
# plant # 20 out of 1122 plant name = Cross
# plant # 21 out of 1122 plant name = Seminole (FL)
# plant # 22 out of 1122 plant name = Agua Fria
# plant # 23 out of 1122 plant name = Kyrene
# plant # 24 out of 1122 plant name = Apache Station
# plant # 25 out of 1122 plant name = GREC
# plant # 26 out of 1122 plant name = Lake Catherine
# plant # 27 out of 1122 plant name = Thomas Fitzhugh
# plant # 28 out of 1122 plant name = Carl Bailey
# plant # 29 out of 1122 plant name = McClellan (AR)
# plant # 30 out of 1122 plant name = Clinton Power Station
# plant # 31 out of 1122 plant name = St Johns River Power Park
# plant # 32 out of 1122 plant name = Wolf Creek Generating Station
# plant # 33 out of 1122 plant name = Dynegy Moss Landing Power Plant
# plant # 34 out of 1122 plant name = Pittsburg Power
# plant # 35 out of 1122 plant name = Limestone
# plant # 36 out of 1122 plant name = Encina
# plant # 37 out of 1122 plant name = AES Alamitos LLC
# plant # 38 out of 1122 plant name = El Segundo Power
# plant # 39 out of 1122 plant name = Etiwanda Generating Station
# plant # 40 out of 1122 plant name = AES Huntington Beach LLC
# plant # 41 out of 1122 plant name = Mandalay
# plant # 42 out of 1122 plant name = Ormond Beach
# plant # 43 out of 1122 plant name = AES Redondo Beach LLC
# plant # 44 out of 1122 plant name = Mountainview Generating Station
# plant # 45 out of 1122 plant name = Columbia Generating Station
# plant # 46 out of 1122 plant name = Grayson
# plant # 47 out of 1122 plant name = Joliet 29
# plant # 48 out of 1122 plant name = El Centro
# plant # 49 out of 1122 plant name = Harbor
# plant # 50 out of 1122 plant name = Haynes
# plant # 51 out of 1122 plant name = Scattergood
# plant # 52 out of 1122 plant name = Valley (CA)
# plant # 53 out of 1122 plant name = Broadway (CA)
# plant # 54 out of 1122 plant name = Cherokee
# plant # 55 out of 1122 plant name = Comanche (CO)
# plant # 56 out of 1122 plant name = Valmont
# plant # 57 out of 1122 plant name = Martin Drake
# plant # 58 out of 1122 plant name = George Birdsall
# plant # 59 out of 1122 plant name = Hayden
# plant # 60 out of 1122 plant name = Nucla
# plant # 61 out of 1122 plant name = McWilliams
# plant # 62 out of 1122 plant name = Montville Station
# plant # 63 out of 1122 plant name = Kettle Falls Generating Station
# plant # 64 out of 1122 plant name = Middletown
# plant # 65 out of 1122 plant name = Stanton Energy Center
# plant # 66 out of 1122 plant name = Millstone
# plant # 67 out of 1122 plant name = Bridgeport Station
# plant # 68 out of 1122 plant name = J C McNeil
# plant # 69 out of 1122 plant name = Edge Moor
# plant # 70 out of 1122 plant name = Indian River Generating Station
# plant # 71 out of 1122 plant name = McKee Run
# plant # 72 out of 1122 plant name = Brandon Shores
# plant # 73 out of 1122 plant name = Cape Canaveral
# plant # 74 out of 1122 plant name = Fort Myers
# plant # 75 out of 1122 plant name = Lauderdale
# plant # 76 out of 1122 plant name = Riviera
# plant # 77 out of 1122 plant name = Sanford
# plant # 78 out of 1122 plant name = Turkey Point
# plant # 79 out of 1122 plant name = Crystal River
# plant # 80 out of 1122 plant name = P L Bartow
# plant # 81 out of 1122 plant name = Suwannee River
# plant # 82 out of 1122 plant name = Crist
# plant # 83 out of 1122 plant name = Scholz
# plant # 84 out of 1122 plant name = Lansing Smith
# plant # 85 out of 1122 plant name = Big Bend
# plant # 86 out of 1122 plant name = Vogtle
# plant # 87 out of 1122 plant name = Deerhaven Generating Station
# plant # 88 out of 1122 plant name = John R Kelly
# plant # 89 out of 1122 plant name = Northside Generating Station
# plant # 90 out of 1122 plant name = Tom G Smith
# plant # 91 out of 1122 plant name = Larsen Memorial
# plant # 92 out of 1122 plant name = C D McIntosh Jr
# plant # 93 out of 1122 plant name = Arvah B Hopkins
# plant # 94 out of 1122 plant name = S O Purdom
# plant # 95 out of 1122 plant name = Vero Beach Municipal Power Plant
# plant # 96 out of 1122 plant name = Bowen
# plant # 97 out of 1122 plant name = Hammond
# plant # 98 out of 1122 plant name = Harllee Branch
# plant # 99 out of 1122 plant name = Jack McDonough
# plant # 100 out of 1122 plant name = McManus
# plant # 101 out of 1122 plant name = Mitchell (GA)
# plant # 102 out of 1122 plant name = Yates
# plant # 103 out of 1122 plant name = Kraft
# plant # 104 out of 1122 plant name = Crisp Plant
# plant # 105 out of 1122 plant name = E D Edwards
# plant # 106 out of 1122 plant name = Coffeen
# plant # 107 out of 1122 plant name = Grand Tower Energy Center LLC
# plant # 108 out of 1122 plant name = Dresden Generating Station
# plant # 109 out of 1122 plant name = Joliet 9
# plant # 110 out of 1122 plant name = Kincaid Generation LLC
# plant # 111 out of 1122 plant name = Powerton
# plant # 112 out of 1122 plant name = Quad Cities Generating Station
# plant # 113 out of 1122 plant name = Waukegan
# plant # 114 out of 1122 plant name = Will County
# plant # 115 out of 1122 plant name = Joppa Steam
# plant # 116 out of 1122 plant name = Baldwin Energy Complex
# plant # 117 out of 1122 plant name = Havana
# plant # 118 out of 1122 plant name = Hennepin Power Station
# plant # 119 out of 1122 plant name = Wood River
# plant # 120 out of 1122 plant name = Dallman
# plant # 121 out of 1122 plant name = Winnetka
# plant # 122 out of 1122 plant name = Marion
# plant # 123 out of 1122 plant name = Clifty Creek
# plant # 124 out of 1122 plant name = Tanners Creek
# plant # 125 out of 1122 plant name = Harding Street
# plant # 126 out of 1122 plant name = Eagle Valley
# plant # 127 out of 1122 plant name = CC Perry K
# plant # 128 out of 1122 plant name = AES Petersburg
# plant # 129 out of 1122 plant name = Bailly
# plant # 130 out of 1122 plant name = Michigan City
# plant # 131 out of 1122 plant name = Cayuga
# plant # 132 out of 1122 plant name = Noblesville
# plant # 133 out of 1122 plant name = R Gallagher
# plant # 134 out of 1122 plant name = Wabash River
# plant # 135 out of 1122 plant name = F B Culley
# plant # 136 out of 1122 plant name = Butler-Warner Generation Plant
# plant # 137 out of 1122 plant name = Logansport
# plant # 138 out of 1122 plant name = Whitewater Valley
# plant # 139 out of 1122 plant name = Frank E Ratts
# plant # 140 out of 1122 plant name = Lansing
# plant # 141 out of 1122 plant name = Milton L Kapp
# plant # 142 out of 1122 plant name = Duane Arnold Energy Center
# plant # 143 out of 1122 plant name = Prairie Creek
# plant # 144 out of 1122 plant name = Sutherland
# plant # 145 out of 1122 plant name = Riverside
# plant # 146 out of 1122 plant name = Walter Scott Jr Energy Center
# plant # 147 out of 1122 plant name = George Neal North
# plant # 148 out of 1122 plant name = Burlington (IA)
# plant # 149 out of 1122 plant name = Ames Electric Services Power Plant
# plant # 150 out of 1122 plant name = Streeter Station
# plant # 151 out of 1122 plant name = Muscatine Plant #1
# plant # 152 out of 1122 plant name = Summit Lake
# plant # 153 out of 1122 plant name = Earl F Wisdom
# plant # 154 out of 1122 plant name = Cimarron River
# plant # 155 out of 1122 plant name = Fort Dodge
# plant # 156 out of 1122 plant name = Gordon Evans Energy Center
# plant # 157 out of 1122 plant name = La Cygne
# plant # 158 out of 1122 plant name = Murray Gill
# plant # 159 out of 1122 plant name = Hutchinson Energy Center
# plant # 160 out of 1122 plant name = Lawrence Energy Center
# plant # 161 out of 1122 plant name = Tecumseh Energy Center
# plant # 162 out of 1122 plant name = Coffeyville
# plant # 163 out of 1122 plant name = Quindaro
# plant # 164 out of 1122 plant name = Pratt
# plant # 165 out of 1122 plant name = Wellington 1
# plant # 166 out of 1122 plant name = Garden City
# plant # 167 out of 1122 plant name = Big Sandy
# plant # 168 out of 1122 plant name = E W Brown
# plant # 169 out of 1122 plant name = Ghent
# plant # 170 out of 1122 plant name = Green River
# plant # 171 out of 1122 plant name = Cane Run
# plant # 172 out of 1122 plant name = Mill Creek (KY)
# plant # 173 out of 1122 plant name = Elmer Smith
# plant # 174 out of 1122 plant name = Paradise
# plant # 175 out of 1122 plant name = Shawnee
# plant # 176 out of 1122 plant name = HMP&L Station Two Henderson
# plant # 177 out of 1122 plant name = Cooper
# plant # 178 out of 1122 plant name = Dale
# plant # 179 out of 1122 plant name = R S Nelson
# plant # 180 out of 1122 plant name = Willow Glen
# plant # 181 out of 1122 plant name = Coughlin Power Station
# plant # 182 out of 1122 plant name = Teche
# plant # 183 out of 1122 plant name = Little Gypsy
# plant # 184 out of 1122 plant name = Nine Mile Point
# plant # 185 out of 1122 plant name = Michoud
# plant # 186 out of 1122 plant name = Arsenal Hill
# plant # 187 out of 1122 plant name = Lieberman
# plant # 188 out of 1122 plant name = Houma
# plant # 189 out of 1122 plant name = Minden
# plant # 190 out of 1122 plant name = Morgan City
# plant # 191 out of 1122 plant name = Plaquemine
# plant # 192 out of 1122 plant name = Big Cajun 1
# plant # 193 out of 1122 plant name = William F Wyman
# plant # 194 out of 1122 plant name = CP Crane Power, LLC
# plant # 195 out of 1122 plant name = Gould Street
# plant # 196 out of 1122 plant name = Herbert A Wagner
# plant # 197 out of 1122 plant name = Vienna Operations
# plant # 198 out of 1122 plant name = Chalk Point LLC
# plant # 199 out of 1122 plant name = Dickerson
# plant # 200 out of 1122 plant name = Morgantown Generating Plant
# plant # 201 out of 1122 plant name = Mystic Generating Station
# plant # 202 out of 1122 plant name = Pilgrim Nuclear Power Station
# plant # 203 out of 1122 plant name = Kendall Square Station
# plant # 204 out of 1122 plant name = Canal
# plant # 205 out of 1122 plant name = Brayton Point
# plant # 206 out of 1122 plant name = Essential Power Massachusetts LLC
# plant # 207 out of 1122 plant name = Cleary Flood
# plant # 208 out of 1122 plant name = B C Cobb
# plant # 209 out of 1122 plant name = Dan E Karn
# plant # 210 out of 1122 plant name = J H Campbell
# plant # 211 out of 1122 plant name = Palisades
# plant # 212 out of 1122 plant name = J C Weadock
# plant # 213 out of 1122 plant name = J R Whiting
# plant # 214 out of 1122 plant name = Fermi
# plant # 215 out of 1122 plant name = Monroe (MI)
# plant # 216 out of 1122 plant name = River Rouge
# plant # 217 out of 1122 plant name = St Clair
# plant # 218 out of 1122 plant name = Trenton Channel
# plant # 219 out of 1122 plant name = Presque Isle
# plant # 220 out of 1122 plant name = Escanaba
# plant # 221 out of 1122 plant name = John H Warden
# plant # 222 out of 1122 plant name = J B Sims
# plant # 223 out of 1122 plant name = James De Young
# plant # 224 out of 1122 plant name = Eckert Station
# plant # 225 out of 1122 plant name = Erickson Station
# plant # 226 out of 1122 plant name = Shiras
# plant # 227 out of 1122 plant name = Wyandotte
# plant # 228 out of 1122 plant name = Fox Lake
# plant # 229 out of 1122 plant name = Syl Laskin
# plant # 230 out of 1122 plant name = Clay Boswell
# plant # 231 out of 1122 plant name = Black Dog
# plant # 232 out of 1122 plant name = High Bridge
# plant # 233 out of 1122 plant name = Allen S King
# plant # 234 out of 1122 plant name = Monticello Nuclear Facility
# plant # 235 out of 1122 plant name = Prairie Island
# plant # 236 out of 1122 plant name = Red Wing
# plant # 237 out of 1122 plant name = Riverside (MN)
# plant # 238 out of 1122 plant name = Wilmarth
# plant # 239 out of 1122 plant name = Hoot Lake
# plant # 240 out of 1122 plant name = Hibbing
# plant # 241 out of 1122 plant name = Hutchinson Plant #1
# plant # 242 out of 1122 plant name = New Ulm
# plant # 243 out of 1122 plant name = Virginia
# plant # 244 out of 1122 plant name = Willmar
# plant # 245 out of 1122 plant name = Elk River
# plant # 246 out of 1122 plant name = Sweatt
# plant # 247 out of 1122 plant name = Jack Watson
# plant # 248 out of 1122 plant name = Baxter Wilson
# plant # 249 out of 1122 plant name = Rex Brown
# plant # 250 out of 1122 plant name = L L Wilkins
# plant # 251 out of 1122 plant name = Henderson
# plant # 252 out of 1122 plant name = Yazoo
# plant # 253 out of 1122 plant name = Moselle
# plant # 254 out of 1122 plant name = Asbury
# plant # 255 out of 1122 plant name = Hawthorn
# plant # 256 out of 1122 plant name = Montrose
# plant # 257 out of 1122 plant name = Sibley
# plant # 258 out of 1122 plant name = Lake Road (MO)
# plant # 259 out of 1122 plant name = Labadie
# plant # 260 out of 1122 plant name = Meramec
# plant # 261 out of 1122 plant name = Sioux
# plant # 262 out of 1122 plant name = Columbia (MO)
# plant # 263 out of 1122 plant name = Blue Valley
# plant # 264 out of 1122 plant name = Marshall (MO)
# plant # 265 out of 1122 plant name = James River Power Station
# plant # 266 out of 1122 plant name = New Madrid
# plant # 267 out of 1122 plant name = Thomas Hill
# plant # 268 out of 1122 plant name = Missouri City
# plant # 269 out of 1122 plant name = J E Corette Plant
# plant # 270 out of 1122 plant name = Canaday
# plant # 271 out of 1122 plant name = Lon Wright
# plant # 272 out of 1122 plant name = Sheldon
# plant # 273 out of 1122 plant name = Fort Calhoun
# plant # 274 out of 1122 plant name = North Omaha
# plant # 275 out of 1122 plant name = Clark (NVE)
# plant # 276 out of 1122 plant name = Reid Gardner
# plant # 277 out of 1122 plant name = Fort Churchill
# plant # 278 out of 1122 plant name = Tracy
# plant # 279 out of 1122 plant name = Merrimack
# plant # 280 out of 1122 plant name = Schiller
# plant # 281 out of 1122 plant name = B L England
# plant # 282 out of 1122 plant name = Oyster Creek
# plant # 283 out of 1122 plant name = Gilbert
# plant # 284 out of 1122 plant name = Bergen Generating Station
# plant # 285 out of 1122 plant name = PSEG Hudson Generating Station
# plant # 286 out of 1122 plant name = PSEG Linden Generating Station
# plant # 287 out of 1122 plant name = PSEG Mercer Generating Station
# plant # 288 out of 1122 plant name = PSEG Salem Generating Station
# plant # 289 out of 1122 plant name = PSEG Sewaren Generating Station
# plant # 290 out of 1122 plant name = Four Corners
# plant # 291 out of 1122 plant name = Rio Grande
# plant # 292 out of 1122 plant name = Maddox
# plant # 293 out of 1122 plant name = Reeves
# plant # 294 out of 1122 plant name = San Juan
# plant # 295 out of 1122 plant name = Cunningham
# plant # 296 out of 1122 plant name = Animas
# plant # 297 out of 1122 plant name = Danskammer Generating Station
# plant # 298 out of 1122 plant name = Arthur Kill Generating Station
# plant # 299 out of 1122 plant name = East River
# plant # 300 out of 1122 plant name = Indian Point 2
# plant # 301 out of 1122 plant name = Ravenswood
# plant # 302 out of 1122 plant name = E F Barrett
# plant # 303 out of 1122 plant name = Northport
# plant # 304 out of 1122 plant name = Port Jefferson
# plant # 305 out of 1122 plant name = Cayuga Operating Company
# plant # 306 out of 1122 plant name = Bethlehem Energy Center
# plant # 307 out of 1122 plant name = C R Huntley Generating Station
# plant # 308 out of 1122 plant name = Dunkirk Generating Plant
# plant # 309 out of 1122 plant name = Nine Mile Point Nuclear Station
# plant # 310 out of 1122 plant name = Oswego Harbor Power
# plant # 311 out of 1122 plant name = Bowline Point
# plant # 312 out of 1122 plant name = S A Carlson
# plant # 313 out of 1122 plant name = Asheville
# plant # 314 out of 1122 plant name = Roxboro
# plant # 315 out of 1122 plant name = G G Allen
# plant # 316 out of 1122 plant name = Buck
# plant # 317 out of 1122 plant name = James E. Rogers Energy Complex
# plant # 318 out of 1122 plant name = Dan River
# plant # 319 out of 1122 plant name = Marshall (NC)
# plant # 320 out of 1122 plant name = R M Heskett
# plant # 321 out of 1122 plant name = Leland Olds
# plant # 322 out of 1122 plant name = Milton R Young
# plant # 323 out of 1122 plant name = Stanton
# plant # 324 out of 1122 plant name = Cardinal
# plant # 325 out of 1122 plant name = Miami Fort
# plant # 326 out of 1122 plant name = FirstEnergy Ashtabula
# plant # 327 out of 1122 plant name = Avon Lake
# plant # 328 out of 1122 plant name = FirstEnergy Eastlake
# plant # 329 out of 1122 plant name = FirstEnergy Lake Shore
# plant # 330 out of 1122 plant name = Conesville
# plant # 331 out of 1122 plant name = J M Stuart
# plant # 332 out of 1122 plant name = FirstEnergy W H Sammis
# plant # 333 out of 1122 plant name = Muskingum River
# plant # 334 out of 1122 plant name = Kyger Creek
# plant # 335 out of 1122 plant name = FirstEnergy Bay Shore
# plant # 336 out of 1122 plant name = Dover
# plant # 337 out of 1122 plant name = Orrville
# plant # 338 out of 1122 plant name = Painesville
# plant # 339 out of 1122 plant name = Horseshoe Lake
# plant # 340 out of 1122 plant name = Muskogee
# plant # 341 out of 1122 plant name = Mustang
# plant # 342 out of 1122 plant name = Seminole (OK)
# plant # 343 out of 1122 plant name = Northeastern
# plant # 344 out of 1122 plant name = Southwestern
# plant # 345 out of 1122 plant name = Tulsa
# plant # 346 out of 1122 plant name = Boomer Lake Station
# plant # 347 out of 1122 plant name = Anadarko Plant
# plant # 348 out of 1122 plant name = Mooreland
# plant # 349 out of 1122 plant name = Brunot Island
# plant # 350 out of 1122 plant name = Conemaugh
# plant # 351 out of 1122 plant name = Homer City Generating Station
# plant # 352 out of 1122 plant name = Seward (PA)
# plant # 353 out of 1122 plant name = Shawville
# plant # 354 out of 1122 plant name = Keystone
# plant # 355 out of 1122 plant name = New Castle Plant
# plant # 356 out of 1122 plant name = Brunner Island
# plant # 357 out of 1122 plant name = TalenEnergy Martins Creek
# plant # 358 out of 1122 plant name = TalenEnergy Montour
# plant # 359 out of 1122 plant name = Eddystone Generating Station
# plant # 360 out of 1122 plant name = Peach Bottom
# plant # 361 out of 1122 plant name = Hunlock Power Station
# plant # 362 out of 1122 plant name = Manchester Street
# plant # 363 out of 1122 plant name = H B Robinson
# plant # 364 out of 1122 plant name = W S Lee
# plant # 365 out of 1122 plant name = Oconee
# plant # 366 out of 1122 plant name = McMeekin
# plant # 367 out of 1122 plant name = Urquhart
# plant # 368 out of 1122 plant name = Wateree
# plant # 369 out of 1122 plant name = Williams
# plant # 370 out of 1122 plant name = Allen Steam Plant
# plant # 371 out of 1122 plant name = Bull Run
# plant # 372 out of 1122 plant name = Cumberland
# plant # 373 out of 1122 plant name = Gallatin (TN)
# plant # 374 out of 1122 plant name = John Sevier
# plant # 375 out of 1122 plant name = Johnsonville
# plant # 376 out of 1122 plant name = Kingston
# plant # 377 out of 1122 plant name = Nueces Bay
# plant # 378 out of 1122 plant name = Victoria
# plant # 379 out of 1122 plant name = Lake Hubbard
# plant # 380 out of 1122 plant name = Mountain Creek
# plant # 381 out of 1122 plant name = Newman
# plant # 382 out of 1122 plant name = Lewis Creek
# plant # 383 out of 1122 plant name = Sabine
# plant # 384 out of 1122 plant name = Cedar Bayou
# plant # 385 out of 1122 plant name = Greens Bayou
# plant # 386 out of 1122 plant name = T H Wharton
# plant # 387 out of 1122 plant name = W A Parish
# plant # 388 out of 1122 plant name = Knox Lee
# plant # 389 out of 1122 plant name = Lone Star
# plant # 390 out of 1122 plant name = Wilkes
# plant # 391 out of 1122 plant name = Jones
# plant # 392 out of 1122 plant name = Nichols
# plant # 393 out of 1122 plant name = Plant X
# plant # 394 out of 1122 plant name = Graham
# plant # 395 out of 1122 plant name = Handley
# plant # 396 out of 1122 plant name = Big Brown
# plant # 397 out of 1122 plant name = Stryker Creek
# plant # 398 out of 1122 plant name = Trinidad (TX)
# plant # 399 out of 1122 plant name = Decker Creek
# plant # 400 out of 1122 plant name = Silas Ray
# plant # 401 out of 1122 plant name = Ray Olinger
# plant # 402 out of 1122 plant name = Sim Gideon
# plant # 403 out of 1122 plant name = Ty Cooke
# plant # 404 out of 1122 plant name = J Robert Massengale
# plant # 405 out of 1122 plant name = O W Sommers
# plant # 406 out of 1122 plant name = V H Braunig
# plant # 407 out of 1122 plant name = R W Miller
# plant # 408 out of 1122 plant name = Pearsall
# plant # 409 out of 1122 plant name = Sam Rayburn
# plant # 410 out of 1122 plant name = Carbon
# plant # 411 out of 1122 plant name = Gadsby
# plant # 412 out of 1122 plant name = Clinch River
# plant # 413 out of 1122 plant name = Glen Lyn
# plant # 414 out of 1122 plant name = Bremo Bluff
# plant # 415 out of 1122 plant name = Chesterfield
# plant # 416 out of 1122 plant name = Possum Point
# plant # 417 out of 1122 plant name = Surry
# plant # 418 out of 1122 plant name = Yorktown
# plant # 419 out of 1122 plant name = Transalta Centralia Generation
# plant # 420 out of 1122 plant name = John E Amos
# plant # 421 out of 1122 plant name = Kanawha River
# plant # 422 out of 1122 plant name = Philip Sporn
# plant # 423 out of 1122 plant name = FirstEnergy Fort Martin Power Station
# plant # 424 out of 1122 plant name = FirstEnergy Harrison Power Station
# plant # 425 out of 1122 plant name = Kammer
# plant # 426 out of 1122 plant name = Mitchell (WV)
# plant # 427 out of 1122 plant name = Mt Storm
# plant # 428 out of 1122 plant name = Bay Front
# plant # 429 out of 1122 plant name = Blount Street
# plant # 430 out of 1122 plant name = French Island
# plant # 431 out of 1122 plant name = Port Washington Generating Station
# plant # 432 out of 1122 plant name = South Oak Creek
# plant # 433 out of 1122 plant name = Valley (WI)
# plant # 434 out of 1122 plant name = Point Beach Nuclear Plant
# plant # 435 out of 1122 plant name = Edgewater
# plant # 436 out of 1122 plant name = Nelson Dewey Generating Station
# plant # 437 out of 1122 plant name = Pulliam
# plant # 438 out of 1122 plant name = Weston
# plant # 439 out of 1122 plant name = Manitowoc
# plant # 440 out of 1122 plant name = Genoa
# plant # 441 out of 1122 plant name = E J Stoneman Station
# plant # 442 out of 1122 plant name = Dave Johnston
# plant # 443 out of 1122 plant name = Naughton
# plant # 444 out of 1122 plant name = Powerlane Plant
# plant # 445 out of 1122 plant name = Endicott Station
# plant # 446 out of 1122 plant name = Spencer
# plant # 447 out of 1122 plant name = Waterford 3
# plant # 448 out of 1122 plant name = John P Madgett
# plant # 449 out of 1122 plant name = Thomas C Ferguson
# plant # 450 out of 1122 plant name = Barney M Davis
# plant # 451 out of 1122 plant name = Riverside
# plant # 452 out of 1122 plant name = Navajo
# plant # 453 out of 1122 plant name = Donald C Cook
# plant # 454 out of 1122 plant name = Joseph M Farley
# plant # 455 out of 1122 plant name = James H Miller Jr
# plant # 456 out of 1122 plant name = FirstEnergy Pleasants Power Station
# plant # 457 out of 1122 plant name = Palo Verde
# plant # 458 out of 1122 plant name = White Bluff
# plant # 459 out of 1122 plant name = Calvert Cliffs Nuclear Power Plant
# plant # 460 out of 1122 plant name = Brunswick Nuclear
# plant # 461 out of 1122 plant name = Harris
# plant # 462 out of 1122 plant name = Duck Creek
# plant # 463 out of 1122 plant name = Newton
# plant # 464 out of 1122 plant name = East Bend
# plant # 465 out of 1122 plant name = W H Zimmer
# plant # 466 out of 1122 plant name = Perry
# plant # 467 out of 1122 plant name = Craig (CO)
# plant # 468 out of 1122 plant name = Braidwood Generation Station
# plant # 469 out of 1122 plant name = Byron Generating Station
# plant # 470 out of 1122 plant name = LaSalle Generating Station
# plant # 471 out of 1122 plant name = Coal Creek
# plant # 472 out of 1122 plant name = Killen Station
# plant # 473 out of 1122 plant name = Belle River
# plant # 474 out of 1122 plant name = Greenwood (MI)
# plant # 475 out of 1122 plant name = Catawba
# plant # 476 out of 1122 plant name = McGuire
# plant # 477 out of 1122 plant name = Beaver Valley
# plant # 478 out of 1122 plant name = H L Spurlock
# plant # 479 out of 1122 plant name = Manatee
# plant # 480 out of 1122 plant name = Martin
# plant # 481 out of 1122 plant name = St Lucie
# plant # 482 out of 1122 plant name = Edwin I Hatch
# plant # 483 out of 1122 plant name = Wansley
# plant # 484 out of 1122 plant name = Big Cajun 2
# plant # 485 out of 1122 plant name = R D Morrow
# plant # 486 out of 1122 plant name = Nearman Creek
# plant # 487 out of 1122 plant name = Iatan
# plant # 488 out of 1122 plant name = Jeffrey Energy Center
# plant # 489 out of 1122 plant name = Trimble County
# plant # 490 out of 1122 plant name = Grand Gulf
# plant # 491 out of 1122 plant name = Victor J Daniel Jr
# plant # 492 out of 1122 plant name = Colstrip
# plant # 493 out of 1122 plant name = Gerald Gentleman
# plant # 494 out of 1122 plant name = Stony Brook
# plant # 495 out of 1122 plant name = Somerset Operating Co LLC
# plant # 496 out of 1122 plant name = R M Schahfer
# plant # 497 out of 1122 plant name = Lewis & Clark
# plant # 498 out of 1122 plant name = Sherburne County
# plant # 499 out of 1122 plant name = FirstEnergy Bruce Mansfield
# plant # 500 out of 1122 plant name = Sooner
# plant # 501 out of 1122 plant name = Nebraska City
# plant # 502 out of 1122 plant name = Big Stone
# plant # 503 out of 1122 plant name = Diablo Canyon
# plant # 504 out of 1122 plant name = TalenEnergy Susquehanna
# plant # 505 out of 1122 plant name = Limerick
# plant # 506 out of 1122 plant name = Boardman
# plant # 507 out of 1122 plant name = James A Fitzpatrick
# plant # 508 out of 1122 plant name = Fort St Vrain
# plant # 509 out of 1122 plant name = Gibson
# plant # 510 out of 1122 plant name = Seabrook
# plant # 511 out of 1122 plant name = PSEG Hope Creek Generating Station
# plant # 512 out of 1122 plant name = R E Ginna Nuclear Power Plant
# plant # 513 out of 1122 plant name = McIntosh
# plant # 514 out of 1122 plant name = V C Summer
# plant # 515 out of 1122 plant name = Gibbons Creek
# plant # 516 out of 1122 plant name = A B Brown
# plant # 517 out of 1122 plant name = Flint Creek
# plant # 518 out of 1122 plant name = Welsh
# plant # 519 out of 1122 plant name = Comanche Peak
# plant # 520 out of 1122 plant name = Martin Lake
# plant # 521 out of 1122 plant name = Monticello
# plant # 522 out of 1122 plant name = Davis Besse
# plant # 523 out of 1122 plant name = Sequoyah
# plant # 524 out of 1122 plant name = Callaway
# plant # 525 out of 1122 plant name = Rush Island
# plant # 526 out of 1122 plant name = New Haven Harbor
# plant # 527 out of 1122 plant name = Hunter
# plant # 528 out of 1122 plant name = Rockport
# plant # 529 out of 1122 plant name = North Anna
# plant # 530 out of 1122 plant name = Pleasant Prairie
# plant # 531 out of 1122 plant name = Coronado
# plant # 532 out of 1122 plant name = Coleto Creek
# plant # 533 out of 1122 plant name = Fayette Power Project
# plant # 534 out of 1122 plant name = Oak Grove (TX)
# plant # 535 out of 1122 plant name = J T Deely
# plant # 536 out of 1122 plant name = San Miguel
# plant # 537 out of 1122 plant name = Brame Energy Center
# plant # 538 out of 1122 plant name = Harrington
# plant # 539 out of 1122 plant name = Tolk
# plant # 540 out of 1122 plant name = John Twitty Energy Center
# plant # 541 out of 1122 plant name = Laramie River Station
# plant # 542 out of 1122 plant name = Merom
# plant # 543 out of 1122 plant name = Dansby
# plant # 544 out of 1122 plant name = Pawnee
# plant # 545 out of 1122 plant name = Winyah
# plant # 546 out of 1122 plant name = Mayo
# plant # 547 out of 1122 plant name = South Texas Project
# plant # 548 out of 1122 plant name = Ottumwa
# plant # 549 out of 1122 plant name = Scherer
# plant # 550 out of 1122 plant name = Mountaineer
# plant # 551 out of 1122 plant name = Hutchinson Plant #2
# plant # 552 out of 1122 plant name = River Bend
# plant # 553 out of 1122 plant name = Antelope Valley
# plant # 554 out of 1122 plant name = Intermountain Power Project
# plant # 555 out of 1122 plant name = D G Hunter
# plant # 556 out of 1122 plant name = R D Green
# plant # 557 out of 1122 plant name = Independence Steam Electric Station
# plant # 558 out of 1122 plant name = Sandow No 4
# plant # 559 out of 1122 plant name = Louisa
# plant # 560 out of 1122 plant name = Warrick
# plant # 561 out of 1122 plant name = Rawhide
# plant # 562 out of 1122 plant name = Sikeston Power Station
# plant # 563 out of 1122 plant name = Hugo
# plant # 564 out of 1122 plant name = D B Wilson
# plant # 565 out of 1122 plant name = East 12th Street
# plant # 566 out of 1122 plant name = Major Oak Power
# plant # 567 out of 1122 plant name = J K Spruce
# plant # 568 out of 1122 plant name = Hay Road
# plant # 569 out of 1122 plant name = Cope
# plant # 570 out of 1122 plant name = Clover
# plant # 571 out of 1122 plant name = Cane Island
# plant # 572 out of 1122 plant name = Central Energy Plant
# plant # 573 out of 1122 plant name = State Line Combined Cycle
# plant # 574 out of 1122 plant name = Hines Energy Complex
# plant # 575 out of 1122 plant name = Redding Power
# plant # 576 out of 1122 plant name = Richard M Flynn
# plant # 577 out of 1122 plant name = George Neal South
# plant # 578 out of 1122 plant name = Coyote Springs
# plant # 579 out of 1122 plant name = Midulla Generating Station
# plant # 580 out of 1122 plant name = Neil Simpson II
# plant # 581 out of 1122 plant name = Arthur Von Rosenberg
# plant # 582 out of 1122 plant name = ReEnergy Fort Fairfield
# plant # 583 out of 1122 plant name = Carson Ice-Gen Project
# plant # 584 out of 1122 plant name = Ponca City
# plant # 585 out of 1122 plant name = Milwaukee County
# plant # 586 out of 1122 plant name = SCA Cogen 2
# plant # 587 out of 1122 plant name = SPA Cogen 3
# plant # 588 out of 1122 plant name = St Francis Energy Facility
# plant # 589 out of 1122 plant name = River Road Gen Plant
# plant # 590 out of 1122 plant name = Washington County Cogeneration Facility
# plant # 591 out of 1122 plant name = General Electric Plastic
# plant # 592 out of 1122 plant name = Tiger Bay
# plant # 593 out of 1122 plant name = Fairless Hills
# plant # 594 out of 1122 plant name = H Allen Franklin Combined Cycle
# plant # 595 out of 1122 plant name = Theodore Cogen Facility
# plant # 596 out of 1122 plant name = Watts Bar Nuclear Plant
# plant # 597 out of 1122 plant name = Kapstone
# plant # 598 out of 1122 plant name = Chouteau
# plant # 599 out of 1122 plant name = Allegany Cogen
# plant # 600 out of 1122 plant name = Bonanza
# plant # 601 out of 1122 plant name = Sherwood H Smith Jr Energy Complex
# plant # 602 out of 1122 plant name = Rowan
# plant # 603 out of 1122 plant name = Roosevelt Biogas 1
# plant # 604 out of 1122 plant name = John S Rainey
# plant # 605 out of 1122 plant name = Lagoon Creek
# plant # 606 out of 1122 plant name = Brandy Branch
# plant # 607 out of 1122 plant name = Encogen
# plant # 608 out of 1122 plant name = H L Culbreath Bayside Power Station
# plant # 609 out of 1122 plant name = Terry Bundy Generating Station
# plant # 610 out of 1122 plant name = E B Harris Electric Generating Plant
# plant # 611 out of 1122 plant name = Sand Hill
# plant # 612 out of 1122 plant name = Pirkey
# plant # 613 out of 1122 plant name = Chattahoochee Energy Facility
# plant # 614 out of 1122 plant name = Coyote Springs II
# plant # 615 out of 1122 plant name = Wansley Unit 9
# plant # 616 out of 1122 plant name = Greater Des Moines
# plant # 617 out of 1122 plant name = West Campus Cogeneration Facility
# plant # 618 out of 1122 plant name = Grays Harbor Energy Facility
# plant # 619 out of 1122 plant name = Beatrice
# plant # 620 out of 1122 plant name = Newington
# plant # 621 out of 1122 plant name = Roseton Generating Facility
# plant # 622 out of 1122 plant name = Three Mile Island
# plant # 623 out of 1122 plant name = Columbia (WI)
# plant # 624 out of 1122 plant name = Emery Station
# plant # 625 out of 1122 plant name = Cooper Nuclear Station
# plant # 626 out of 1122 plant name = Belews Creek
# plant # 627 out of 1122 plant name = Anclote
# plant # 628 out of 1122 plant name = Gerald Andrus
# plant # 629 out of 1122 plant name = Arkansas Nuclear One
# plant # 630 out of 1122 plant name = Waterford 1 & 2
# plant # 631 out of 1122 plant name = Comanche (OK)
# plant # 632 out of 1122 plant name = Jim Bridger
# plant # 633 out of 1122 plant name = Santan
# plant # 634 out of 1122 plant name = Huntington
# plant # 635 out of 1122 plant name = Beaver
# plant # 636 out of 1122 plant name = General James M Gavin
# plant # 637 out of 1122 plant name = Ray D Nixon
# plant # 638 out of 1122 plant name = Coyote
# plant # 639 out of 1122 plant name = Springerville
# plant # 640 out of 1122 plant name = North Valmy
# plant # 641 out of 1122 plant name = Cheswick Power Plant
# plant # 642 out of 1122 plant name = Astoria Generating Station
# plant # 643 out of 1122 plant name = Indian Point 3
# plant # 644 out of 1122 plant name = Colorado Energy Nations Company
# plant # 645 out of 1122 plant name = Covanta Warren Energy
# plant # 646 out of 1122 plant name = Covanta Hennepin Energy
# plant # 647 out of 1122 plant name = NRG Energy Center Dover
# plant # 648 out of 1122 plant name = Gilroy Power Plant
# plant # 649 out of 1122 plant name = Logan Generating Company LP
# plant # 650 out of 1122 plant name = Fairhaven Power
# plant # 651 out of 1122 plant name = Miami Dade County Resource Recovery Fac
# plant # 652 out of 1122 plant name = Portsmouth Genco LLC
# plant # 653 out of 1122 plant name = Taconite Harbor Energy Center
# plant # 654 out of 1122 plant name = Commerce Refuse To Energy
# plant # 655 out of 1122 plant name = Pedricktown Cogeneration Company LP
# plant # 656 out of 1122 plant name = John B Rich Memorial Power Station
# plant # 657 out of 1122 plant name = Harrisburg Facility
# plant # 658 out of 1122 plant name = Colver Power Project
# plant # 659 out of 1122 plant name = White Pine Electric Power
# plant # 660 out of 1122 plant name = Grant Town Power Plant
# plant # 661 out of 1122 plant name = Fresno Cogen Partners
# plant # 662 out of 1122 plant name = Cardinal Cogen
# plant # 663 out of 1122 plant name = Carson Cogeneration
# plant # 664 out of 1122 plant name = Castleton Energy Center
# plant # 665 out of 1122 plant name = Bay County Waste to Energy
# plant # 666 out of 1122 plant name = King City Power Plant
# plant # 667 out of 1122 plant name = Desert View Power
# plant # 668 out of 1122 plant name = Florida Power Development
# plant # 669 out of 1122 plant name = Foster Wheeler Martinez
# plant # 670 out of 1122 plant name = Foster Wheeler Mt Carmel Cogen
# plant # 671 out of 1122 plant name = Hillman Power LLC
# plant # 672 out of 1122 plant name = Greenleaf 1 Power Plant
# plant # 673 out of 1122 plant name = ReEnergy Livermore Falls
# plant # 674 out of 1122 plant name = ReEnergy Ashland
# plant # 675 out of 1122 plant name = James River Genco LLC
# plant # 676 out of 1122 plant name = CPI USA NC Southport
# plant # 677 out of 1122 plant name = CPI USA NC Roxboro
# plant # 678 out of 1122 plant name = Lumberton
# plant # 679 out of 1122 plant name = Edgecombe Genco LLC
# plant # 680 out of 1122 plant name = GRS Coyote Canyon
# plant # 681 out of 1122 plant name = Kingsburg Cogen
# plant # 682 out of 1122 plant name = Camden Resource Recovery Facility
# plant # 683 out of 1122 plant name = ReEnergy Black River
# plant # 684 out of 1122 plant name = Rumford Cogeneration
# plant # 685 out of 1122 plant name = Wheelabrator Hudson Falls
# plant # 686 out of 1122 plant name = Craven County Wood Energy LP
# plant # 687 out of 1122 plant name = Chambers Cogeneration LP
# plant # 688 out of 1122 plant name = Algonquin Windsor Locks
# plant # 689 out of 1122 plant name = Agrilectric Power Partners Ltd
# plant # 690 out of 1122 plant name = Ebensburg Power
# plant # 691 out of 1122 plant name = CH Resources Beaver Falls
# plant # 692 out of 1122 plant name = Carthage Energy LLC
# plant # 693 out of 1122 plant name = CH Resources Syracuse
# plant # 694 out of 1122 plant name = Wheelabrator Baltimore Refuse
# plant # 695 out of 1122 plant name = Hopewell Cogeneration
# plant # 696 out of 1122 plant name = Cambria Cogen
# plant # 697 out of 1122 plant name = Covanta Hempstead
# plant # 698 out of 1122 plant name = Covanta Southeastern Connecticut Company
# plant # 699 out of 1122 plant name = Burney Forest Products
# plant # 700 out of 1122 plant name = AES Shady Point LLC
# plant # 701 out of 1122 plant name = Cedar Bay Generating Company LP
# plant # 702 out of 1122 plant name = AES Warrior Run Cogeneration Facility
# plant # 703 out of 1122 plant name = Brush Generation Facility
# plant # 704 out of 1122 plant name = Rapids Energy Center
# plant # 705 out of 1122 plant name = Selkirk Cogen
# plant # 706 out of 1122 plant name = Masspower
# plant # 707 out of 1122 plant name = Clear Lake Cogeneration Ltd
# plant # 708 out of 1122 plant name = Morgantown Energy Facility
# plant # 709 out of 1122 plant name = Midland Cogeneration Venture
# plant # 710 out of 1122 plant name = Covanta Delaware Valley
# plant # 711 out of 1122 plant name = Camden Plant Holding LLC
# plant # 712 out of 1122 plant name = Las Vegas Generating Station
# plant # 713 out of 1122 plant name = Blue Lake Power LLC
# plant # 714 out of 1122 plant name = Indeck Jonesboro Energy Center
# plant # 715 out of 1122 plant name = Indeck West Enfield Energy Center
# plant # 716 out of 1122 plant name = Rio Bravo Fresno
# plant # 717 out of 1122 plant name = Hopewell Power Station
# plant # 718 out of 1122 plant name = Rio Bravo Rocklin
# plant # 719 out of 1122 plant name = Altavista Power Station
# plant # 720 out of 1122 plant name = Southampton Power Station
# plant # 721 out of 1122 plant name = HL Power
# plant # 722 out of 1122 plant name = Colstrip Energy LP
# plant # 723 out of 1122 plant name = Kenilworth Energy Facility
# plant # 724 out of 1122 plant name = NTC_MCRD_Energy_Facility
# plant # 725 out of 1122 plant name = Naval Station Energy Facility
# plant # 726 out of 1122 plant name = North Island Energy Facility
# plant # 727 out of 1122 plant name = Ada Cogeneration LP
# plant # 728 out of 1122 plant name = Grayling Generating Station
# plant # 729 out of 1122 plant name = Woodland Biomass Power Ltd
# plant # 730 out of 1122 plant name = Covanta Mendota
# plant # 731 out of 1122 plant name = Springfield Power LLC
# plant # 732 out of 1122 plant name = DG Whitefield LLC
# plant # 733 out of 1122 plant name = Covanta Delano Energy
# plant # 734 out of 1122 plant name = Biomass One LP
# plant # 735 out of 1122 plant name = Pittsfield Generating LP
# plant # 736 out of 1122 plant name = Palm Beach Renewable Energy Facility 1
# plant # 737 out of 1122 plant name = Tamarack Energy Partnership
# plant # 738 out of 1122 plant name = Paris Energy Center
# plant # 739 out of 1122 plant name = CCI Signal Hill LLC
# plant # 740 out of 1122 plant name = Rabun Gap Cogen Facility
# plant # 741 out of 1122 plant name = Pinetree Power
# plant # 742 out of 1122 plant name = York County Resource Recovery
# plant # 743 out of 1122 plant name = Regional Waste Systems
# plant # 744 out of 1122 plant name = Bucksport Generation LLC
# plant # 745 out of 1122 plant name = Pioneer Valley Resource Recovery
# plant # 746 out of 1122 plant name = Archbald Power Station
# plant # 747 out of 1122 plant name = SEMASS Resource Recovery
# plant # 748 out of 1122 plant name = Bethpage Power Plant
# plant # 749 out of 1122 plant name = Wadham Energy LP
# plant # 750 out of 1122 plant name = Newark Bay Cogeneration Partnership LP
# plant # 751 out of 1122 plant name = Mobile Energy Services LLC
# plant # 752 out of 1122 plant name = Indeck Silver Springs Energy Center
# plant # 753 out of 1122 plant name = Indeck Oswego Energy Center
# plant # 754 out of 1122 plant name = Indeck Yerkes Energy Center
# plant # 755 out of 1122 plant name = Indeck Corinth Energy Center
# plant # 756 out of 1122 plant name = Covanta Niagara LP
# plant # 757 out of 1122 plant name = Bayonne Plant Holding LLC
# plant # 758 out of 1122 plant name = Capital District Energy Center
# plant # 759 out of 1122 plant name = Harbor Cogen
# plant # 760 out of 1122 plant name = Rosemary Power Station
# plant # 761 out of 1122 plant name = Oklahoma Cogeneration Project
# plant # 762 out of 1122 plant name = Pacific-Ultrapower Chinese Station
# plant # 763 out of 1122 plant name = Eagle Point Power Generation
# plant # 764 out of 1122 plant name = CSL Gas Recovery
# plant # 765 out of 1122 plant name = Westwood Generation LLC
# plant # 766 out of 1122 plant name = Covanta Lake County Energy
# plant # 767 out of 1122 plant name = Covanta Marion Inc
# plant # 768 out of 1122 plant name = Covanta Stanislaus Energy
# plant # 769 out of 1122 plant name = Covanta Bristol Energy
# plant # 770 out of 1122 plant name = ReEnergy Stratton LLC
# plant # 771 out of 1122 plant name = Montgomery County Resource Recovery
# plant # 772 out of 1122 plant name = Covanta Fairfax Energy
# plant # 773 out of 1122 plant name = Pasco Cnty Solid Waste Resource Recovery
# plant # 774 out of 1122 plant name = JM Shafer Generating Station
# plant # 775 out of 1122 plant name = Pinetree Power Tamworth
# plant # 776 out of 1122 plant name = Sterling Power Plant
# plant # 777 out of 1122 plant name = Agnews Power Plant
# plant # 778 out of 1122 plant name = Viking Energy of McBain
# plant # 779 out of 1122 plant name = Viking Energy of Lincoln
# plant # 780 out of 1122 plant name = Telogia Power
# plant # 781 out of 1122 plant name = Panther Creek Energy Facility
# plant # 782 out of 1122 plant name = Parlin Power Plant
# plant # 783 out of 1122 plant name = Optim Energy Altura Cogen LLC
# plant # 784 out of 1122 plant name = TES Filer City Station
# plant # 785 out of 1122 plant name = Southeast Resource Recovery
# plant # 786 out of 1122 plant name = OLS Energy Chino
# plant # 787 out of 1122 plant name = CSUCI Site Authority
# plant # 788 out of 1122 plant name = Elmwood Energy Holdings LLC
# plant # 789 out of 1122 plant name = Hillsborough County Resource Recovery
# plant # 790 out of 1122 plant name = Lancaster County Resource Recovery
# plant # 791 out of 1122 plant name = Wheelabrator Concord Facility
# plant # 792 out of 1122 plant name = McKay Bay Facility
# plant # 793 out of 1122 plant name = Wheelabrator Norwalk Energy
# plant # 794 out of 1122 plant name = Wheelabrator North Andover
# plant # 795 out of 1122 plant name = Wheelabrator Millbury Facility
# plant # 796 out of 1122 plant name = Wheelabrator Frackville Energy
# plant # 797 out of 1122 plant name = Wheelabrator Saugus
# plant # 798 out of 1122 plant name = Wheelabrator Shasta
# plant # 799 out of 1122 plant name = Wheelabrator Westchester
# plant # 800 out of 1122 plant name = Wheelabrator Bridgeport
# plant # 801 out of 1122 plant name = Pinellas County Resource Recovery
# plant # 802 out of 1122 plant name = Wheelabrator Gloucester LP
# plant # 803 out of 1122 plant name = Spokane Waste to Energy
# plant # 804 out of 1122 plant name = Wheelabrator South Broward
# plant # 805 out of 1122 plant name = Northampton Generating Company LP
# plant # 806 out of 1122 plant name = Hardee Power Station
# plant # 807 out of 1122 plant name = Sunnyside Cogen Associates
# plant # 808 out of 1122 plant name = Bellmeade Power Station
# plant # 809 out of 1122 plant name = Scrubgrass Generating Company LP
# plant # 810 out of 1122 plant name = Indiantown Cogeneration LP
# plant # 811 out of 1122 plant name = Carr Street Generating Station
# plant # 812 out of 1122 plant name = Ryegate Power Station
# plant # 813 out of 1122 plant name = Ocean State Power
# plant # 814 out of 1122 plant name = Mecklenburg Power Station
# plant # 815 out of 1122 plant name = Lee County Solid Waste Energy
# plant # 816 out of 1122 plant name = Nassau Energy Corp
# plant # 817 out of 1122 plant name = Sandow No 5
# plant # 818 out of 1122 plant name = Texas City Power Plant
# plant # 819 out of 1122 plant name = Multitrade of Pittsylvania LP
# plant # 820 out of 1122 plant name = C R Wing Cogen Plant
# plant # 821 out of 1122 plant name = MM West Covina
# plant # 822 out of 1122 plant name = Wheelabrator North Broward
# plant # 823 out of 1122 plant name = Rensselaer Cogen
# plant # 824 out of 1122 plant name = Roanoke Valley Energy Facility I
# plant # 825 out of 1122 plant name = Lockport Energy Associates LP
# plant # 826 out of 1122 plant name = Pawtucket Power Associates
# plant # 827 out of 1122 plant name = Indeck Olean Energy Center
# plant # 828 out of 1122 plant name = Spruance Genco LLC
# plant # 829 out of 1122 plant name = Kennedy International Airport Cogen
# plant # 830 out of 1122 plant name = Fortistar North Tonawanda
# plant # 831 out of 1122 plant name = Stockton Biomass
# plant # 832 out of 1122 plant name = Saguaro Power
# plant # 833 out of 1122 plant name = Birchwood Power
# plant # 834 out of 1122 plant name = Ocean State Power II
# plant # 835 out of 1122 plant name = Nevada Cogen Associates 2 Black Mountain
# plant # 836 out of 1122 plant name = Nevada Cogen Assoc#1 GarnetVly
# plant # 837 out of 1122 plant name = Orange Cogeneration Facility
# plant # 838 out of 1122 plant name = Cadillac Renewable Energy
# plant # 839 out of 1122 plant name = Quantum Pasco Power LP
# plant # 840 out of 1122 plant name = Mulberry Cogeneration Facility
# plant # 841 out of 1122 plant name = Orlando Cogen LP
# plant # 842 out of 1122 plant name = Sumas Power Plant
# plant # 843 out of 1122 plant name = ReEnergy Lyonsdale Biomass
# plant # 844 out of 1122 plant name = Wheelabrator Ridge Energy
# plant # 845 out of 1122 plant name = Ferndale Generating Station
# plant # 846 out of 1122 plant name = Sithe Independence Station
# plant # 847 out of 1122 plant name = Jefferson Smurfit Santa Clara Mill
# plant # 848 out of 1122 plant name = Rupert Cogen Project
# plant # 849 out of 1122 plant name = Tanner Street Generation
# plant # 850 out of 1122 plant name = Massena Energy Facility
# plant # 851 out of 1122 plant name = Batavia Power Plant
# plant # 852 out of 1122 plant name = Mt Poso Cogeneration
# plant # 853 out of 1122 plant name = Okeelanta Cogeneration
# plant # 854 out of 1122 plant name = St Nicholas Cogen Project
# plant # 855 out of 1122 plant name = NAEA Lakewood LLC
# plant # 856 out of 1122 plant name = Oyster Creek Unit VIII
# plant # 857 out of 1122 plant name = York Generation Company LLC
# plant # 858 out of 1122 plant name = Yuma Cogeneration Associates
# plant # 859 out of 1122 plant name = Wheelabrator Falls
# plant # 860 out of 1122 plant name = Goal Line LP
# plant # 861 out of 1122 plant name = Genesee Power Station LP
# plant # 862 out of 1122 plant name = Roanoke Valley Energy Facility II
# plant # 863 out of 1122 plant name = Wheelabrator Lisbon
# plant # 864 out of 1122 plant name = Hermiston Generating Plant
# plant # 865 out of 1122 plant name = Grays Ferry Cogeneration
# plant # 866 out of 1122 plant name = Milford Power LP
# plant # 867 out of 1122 plant name = Johnson County
# plant # 868 out of 1122 plant name = Brandywine Power Facility
# plant # 869 out of 1122 plant name = Brooklyn Navy Yard Cogeneration
# plant # 870 out of 1122 plant name = Michigan Power LP
# plant # 871 out of 1122 plant name = CT Resource Rec Authority Facility
# plant # 872 out of 1122 plant name = Sauder Power Plant
# plant # 873 out of 1122 plant name = LSP-Cottage Grove LP
# plant # 874 out of 1122 plant name = LSP-Whitewater LP
# plant # 875 out of 1122 plant name = Mid-Georgia Cogeneration Facility
# plant # 876 out of 1122 plant name = Berkshire Power
# plant # 877 out of 1122 plant name = Bridgeport Energy Project
# plant # 878 out of 1122 plant name = Cherokee County Cogen
# plant # 879 out of 1122 plant name = Pasadena Cogeneration
# plant # 880 out of 1122 plant name = Tenaska Frontier Generation Station
# plant # 881 out of 1122 plant name = Batesville Generation Facility
# plant # 882 out of 1122 plant name = Mustang Station
# plant # 883 out of 1122 plant name = Maine Independence Station
# plant # 884 out of 1122 plant name = Pine Bluff Energy Center
# plant # 885 out of 1122 plant name = Red Hills Generating Facility
# plant # 886 out of 1122 plant name = Millennium Power
# plant # 887 out of 1122 plant name = Gregory Power Facility
# plant # 888 out of 1122 plant name = Zeeland Generating Station
# plant # 889 out of 1122 plant name = Dearborn Industrial Generation
# plant # 890 out of 1122 plant name = Plummer Cogen
# plant # 891 out of 1122 plant name = Portside Energy
# plant # 892 out of 1122 plant name = Lamar Power Project
# plant # 893 out of 1122 plant name = Frontera Energy Center
# plant # 894 out of 1122 plant name = Rumford Power, Inc
# plant # 895 out of 1122 plant name = Klamath Cogeneration Plant
# plant # 896 out of 1122 plant name = Sabine Cogen
# plant # 897 out of 1122 plant name = Rhode Island State Energy Center
# plant # 898 out of 1122 plant name = Magic Valley Generating Station
# plant # 899 out of 1122 plant name = Griffith Energy LLC
# plant # 900 out of 1122 plant name = Milford Power Project
# plant # 901 out of 1122 plant name = Desert Basin
# plant # 902 out of 1122 plant name = Kendall County Generation Facility
# plant # 903 out of 1122 plant name = Tenaska Gateway Generating Station
# plant # 904 out of 1122 plant name = Rio Nogales Power Project
# plant # 905 out of 1122 plant name = Wolf Hollow I LP
# plant # 906 out of 1122 plant name = Hays Energy Project
# plant # 907 out of 1122 plant name = Green Country Energy LLC
# plant # 908 out of 1122 plant name = La Paloma Generating LLC
# plant # 909 out of 1122 plant name = Guadalupe Generating Station
# plant # 910 out of 1122 plant name = Lost Pines 1 Power Project
# plant # 911 out of 1122 plant name = Bastrop Energy Center
# plant # 912 out of 1122 plant name = Granite Ridge
# plant # 913 out of 1122 plant name = Bosque County Peaking
# plant # 914 out of 1122 plant name = Acadia Energy Center
# plant # 915 out of 1122 plant name = Eastman Cogeneration Facility
# plant # 916 out of 1122 plant name = South Point Energy Center
# plant # 917 out of 1122 plant name = Dogwood Energy Facility
# plant # 918 out of 1122 plant name = Rathdrum Power LLC
# plant # 919 out of 1122 plant name = Sunrise Power LLC
# plant # 920 out of 1122 plant name = Nelson Energy Center
# plant # 921 out of 1122 plant name = Channelview Cogeneration Plant
# plant # 922 out of 1122 plant name = Cordova Energy
# plant # 923 out of 1122 plant name = Ontelaunee Energy Center
# plant # 924 out of 1122 plant name = Caledonia
# plant # 925 out of 1122 plant name = Arapahoe Combustion Turbine Project
# plant # 926 out of 1122 plant name = Corpus Christi Energy Center
# plant # 927 out of 1122 plant name = Afton Generating Station
# plant # 928 out of 1122 plant name = Odessa Ector Generating Station
# plant # 929 out of 1122 plant name = Morris Cogeneration LLC
# plant # 930 out of 1122 plant name = Los Medanos Energy Center
# plant # 931 out of 1122 plant name = Hinds Energy Facility
# plant # 932 out of 1122 plant name = Attala
# plant # 933 out of 1122 plant name = Harry L. Oswald
# plant # 934 out of 1122 plant name = Ennis Power Company LLC
# plant # 935 out of 1122 plant name = Oneta Energy Center
# plant # 936 out of 1122 plant name = Freestone Energy Center
# plant # 937 out of 1122 plant name = Jack County
# plant # 938 out of 1122 plant name = Liberty Electric Power Plant
# plant # 939 out of 1122 plant name = Red Oak Power LLC
# plant # 940 out of 1122 plant name = Hog Bayou Energy Center
# plant # 941 out of 1122 plant name = Santa Rosa Energy Center
# plant # 942 out of 1122 plant name = Whiting Clean Energy
# plant # 943 out of 1122 plant name = TVA Southaven Combined Cycle
# plant # 944 out of 1122 plant name = Jackson Generating Station
# plant # 945 out of 1122 plant name = Tenaska Lindsay Hill Generating Station
# plant # 946 out of 1122 plant name = Arlington Valley Energy Facility
# plant # 947 out of 1122 plant name = Decatur Energy Center
# plant # 948 out of 1122 plant name = Morgan Energy Center
# plant # 949 out of 1122 plant name = Westbrook Energy Center Power Plant
# plant # 950 out of 1122 plant name = Blythe Energy Inc
# plant # 951 out of 1122 plant name = New Covert Generating Facility
# plant # 952 out of 1122 plant name = Fairless Energy Center
# plant # 953 out of 1122 plant name = Channel Energy Center LLC
# plant # 954 out of 1122 plant name = Wasatch Energy Systems Energy Recovery
# plant # 955 out of 1122 plant name = Gila River Power Station
# plant # 956 out of 1122 plant name = Wise County Power LLC
# plant # 957 out of 1122 plant name = Baytown Energy Center
# plant # 958 out of 1122 plant name = Hermiston Power Partnership
# plant # 959 out of 1122 plant name = Delta Energy Center
# plant # 960 out of 1122 plant name = Holland Energy Facility
# plant # 961 out of 1122 plant name = TalenEnergy Ironwood LLC
# plant # 962 out of 1122 plant name = Dell Power Station
# plant # 963 out of 1122 plant name = Luna Energy Facility
# plant # 964 out of 1122 plant name = Dresden Energy Facility
# plant # 965 out of 1122 plant name = Brazos Valley Generating Facility
# plant # 966 out of 1122 plant name = Cottonwood Energy Project
# plant # 967 out of 1122 plant name = Sugar Creek Power
# plant # 968 out of 1122 plant name = Harquahala Generating Project
# plant # 969 out of 1122 plant name = Union Power Partners LP
# plant # 970 out of 1122 plant name = KGen Murray I and II LLC
# plant # 971 out of 1122 plant name = Columbia Energy Center (SC)
# plant # 972 out of 1122 plant name = Metcalf Energy Center
# plant # 973 out of 1122 plant name = Washington Energy Facility
# plant # 974 out of 1122 plant name = Elk Hills Power LLC
# plant # 975 out of 1122 plant name = Carville Energy LLC
# plant # 976 out of 1122 plant name = Effingham County Power Project
# plant # 977 out of 1122 plant name = Hillabee Energy Center
# plant # 978 out of 1122 plant name = Osprey Energy Center Power Plant
# plant # 979 out of 1122 plant name = Hot Spring Generating Facility
# plant # 980 out of 1122 plant name = Tenaska Virginia Generating Station
# plant # 981 out of 1122 plant name = Tenaska Central Alabama Generating Stn
# plant # 982 out of 1122 plant name = Magnolia Power Plant
# plant # 983 out of 1122 plant name = Red Hawk
# plant # 984 out of 1122 plant name = McClain Energy Facility
# plant # 985 out of 1122 plant name = Redbud Power Plant
# plant # 986 out of 1122 plant name = Deer Park Energy Center
# plant # 987 out of 1122 plant name = Ouachita
# plant # 988 out of 1122 plant name = Forney Energy Center
# plant # 989 out of 1122 plant name = Mesquite Generating Station Block 2
# plant # 990 out of 1122 plant name = Goldendale Generating Station
# plant # 991 out of 1122 plant name = Kiamichi Energy Facility
# plant # 992 out of 1122 plant name = Lawrenceburg Energy Facility
# plant # 993 out of 1122 plant name = AEP Waterford Facility
# plant # 994 out of 1122 plant name = Fayette Energy Facility
# plant # 995 out of 1122 plant name = High Desert Power Plant
# plant # 996 out of 1122 plant name = York Energy Center
# plant # 997 out of 1122 plant name = Hidalgo Energy Center
# plant # 998 out of 1122 plant name = Perryville Power Station
# plant # 999 out of 1122 plant name = Riverside Energy Center
# plant # 1000 out of 1122 plant name = Pastoria Energy Facility, LLC
# plant # 1001 out of 1122 plant name = Essential Power Newington LLC
# plant # 1002 out of 1122 plant name = Harrison County Power Project
# plant # 1003 out of 1122 plant name = Lower Mount Bethel Energy
# plant # 1004 out of 1122 plant name = Bethlehem Power Plant
# plant # 1005 out of 1122 plant name = Quantum Choctaw Power LLC
# plant # 1006 out of 1122 plant name = Mint Farm Generating Station
# plant # 1007 out of 1122 plant name = Fremont Energy Center
# plant # 1008 out of 1122 plant name = Nacogdoches Power
# plant # 1009 out of 1122 plant name = FirstEnergy Allegheny Energy Units 3 4 & 5
# plant # 1010 out of 1122 plant name = Magnet Cove
# plant # 1011 out of 1122 plant name = Hanging Rock Energy Facility
# plant # 1012 out of 1122 plant name = Los Esteros Critical Energy Center
# plant # 1013 out of 1122 plant name = Hardin Generator Project
# plant # 1014 out of 1122 plant name = FPL Energy Marcus Hook LP
# plant # 1015 out of 1122 plant name = Frederickson Power LP
# plant # 1016 out of 1122 plant name = Curtis H Stanton Energy Center
# plant # 1017 out of 1122 plant name = Rocky Mountain Energy Center
# plant # 1018 out of 1122 plant name = Inland Empire Energy Center
# plant # 1019 out of 1122 plant name = Prairie State Generating Station
# plant # 1020 out of 1122 plant name = Jasper
# plant # 1021 out of 1122 plant name = Wansley Combined Cycle
# plant # 1022 out of 1122 plant name = Cosumnes
# plant # 1023 out of 1122 plant name = Bluffview
# plant # 1024 out of 1122 plant name = Palomar Energy
# plant # 1025 out of 1122 plant name = Ashtabula
# plant # 1026 out of 1122 plant name = Donald Von Raesfeld Power Plant
# plant # 1027 out of 1122 plant name = Fox Energy Center
# plant # 1028 out of 1122 plant name = Malburg
# plant # 1029 out of 1122 plant name = Magnolia Power Project
# plant # 1030 out of 1122 plant name = Elm Road Generating Station
# plant # 1031 out of 1122 plant name = Walnut Energy Center
# plant # 1032 out of 1122 plant name = Riceland Foods Cogeneration Plant
# plant # 1033 out of 1122 plant name = Mankato Energy Center
# plant # 1034 out of 1122 plant name = Middlesex Generating Facility
# plant # 1035 out of 1122 plant name = McIntosh Combined Cycle Facility
# plant # 1036 out of 1122 plant name = Faribault Energy Park
# plant # 1037 out of 1122 plant name = Nebo Power Station
# plant # 1038 out of 1122 plant name = Pinelawn Power LLC
# plant # 1039 out of 1122 plant name = TS Power Plant
# plant # 1040 out of 1122 plant name = Port Westward
# plant # 1041 out of 1122 plant name = Lake Side Power Plant
# plant # 1042 out of 1122 plant name = Empire Generating Co  LLC
# plant # 1043 out of 1122 plant name = Roseville Energy Park
# plant # 1044 out of 1122 plant name = Trigen St. Louis
# plant # 1045 out of 1122 plant name = Wygen 2
# plant # 1046 out of 1122 plant name = Quail Run Energy Center
# plant # 1047 out of 1122 plant name = Colorado Bend Energy Center
# plant # 1048 out of 1122 plant name = Clearwater Power Plant
# plant # 1049 out of 1122 plant name = Treasure Coast Energy Center
# plant # 1050 out of 1122 plant name = West County Energy Center
# plant # 1051 out of 1122 plant name = Plum Point Energy Station
# plant # 1052 out of 1122 plant name = Russell City Energy Center
# plant # 1053 out of 1122 plant name = John W Turk Jr Power Plant
# plant # 1054 out of 1122 plant name = J Lamar Stall Unit
# plant # 1055 out of 1122 plant name = Sandy Creek Energy Station
# plant # 1056 out of 1122 plant name = Novo BioPower Plant
# plant # 1057 out of 1122 plant name = St Paul Cogeneration
# plant # 1058 out of 1122 plant name = Longview Power Plant
# plant # 1059 out of 1122 plant name = Ampersand Chowchilla Biomass LLC
# plant # 1060 out of 1122 plant name = El Nido Facility
# plant # 1061 out of 1122 plant name = Spiritwood Station
# plant # 1062 out of 1122 plant name = Kleen Energy Systems Project
# plant # 1063 out of 1122 plant name = Cedar Bayou 4
# plant # 1064 out of 1122 plant name = Bear Garden
# plant # 1065 out of 1122 plant name = Plainfield Renewable Energy LLC
# plant # 1066 out of 1122 plant name = Haverhill North Cogeneration Facility
# plant # 1067 out of 1122 plant name = Aspen Biomass Power Plant
# plant # 1068 out of 1122 plant name = West Deptford Energy Station
# plant # 1069 out of 1122 plant name = Pueblo Airport Generating Station
# plant # 1070 out of 1122 plant name = Langley Gulch Power Plant
# plant # 1071 out of 1122 plant name = Kemper County IGCC Project
# plant # 1072 out of 1122 plant name = Koda Biomass Plant
# plant # 1073 out of 1122 plant name = Savannah River Site Biomass Cogen
# plant # 1074 out of 1122 plant name = Gainesville Renewable Energy Center
# plant # 1075 out of 1122 plant name = Garrison Energy Center LLC
# plant # 1076 out of 1122 plant name = Algonquin Power Sanger LLC
# plant # 1077 out of 1122 plant name = Cheyenne Prairie Generating Station
# plant # 1078 out of 1122 plant name = Middletown Coke Company, LLC
# plant # 1079 out of 1122 plant name = Woodbridge Energy Center
# plant # 1080 out of 1122 plant name = Palm Beach Renewable Energy Facility 2
# plant # 1081 out of 1122 plant name = Piedmont Green Power
# plant # 1082 out of 1122 plant name = Lodi Energy Center
# plant # 1083 out of 1122 plant name = Panda Temple Power Station
# plant # 1084 out of 1122 plant name = Panda Sherman Power Station
# plant # 1085 out of 1122 plant name = Brea Expansion Plant
# plant # 1086 out of 1122 plant name = Burgess BioPower
# plant # 1087 out of 1122 plant name = Newark Energy Center
# plant # 1088 out of 1122 plant name = Rothschild Biomass Cogen Facility
# plant # 1089 out of 1122 plant name = Grand Ave Plant
# plant # 1090 out of 1122 plant name = Lee Combined Cycle Plant
# plant # 1091 out of 1122 plant name = Lansing BWL REO Town Plant
# plant # 1092 out of 1122 plant name = Buena Vista Biomass Power
# plant # 1093 out of 1122 plant name = WSACC Power Generation Facility
# plant # 1094 out of 1122 plant name = Mesquite Generating Station Block 1
# plant # 1095 out of 1122 plant name = Halifax County Biomass
# plant # 1096 out of 1122 plant name = Eagle Valley Clean Energy LLC Biomass
# plant # 1097 out of 1122 plant name = Indeck Energy-Alexandria
# plant # 1098 out of 1122 plant name = L V Sutton Combined Cycle
# plant # 1099 out of 1122 plant name = Allendale Biomass
# plant # 1100 out of 1122 plant name = Dorchester Biomass
# plant # 1101 out of 1122 plant name = Woodville Renewable Power Project
# plant # 1102 out of 1122 plant name = Johnston LFG Turbine Plant
# plant # 1103 out of 1122 plant name = Sundevil Power Holdings - Gila River
# plant # 1104 out of 1122 plant name = Gila River Power Block 3
# plant # 1105 out of 1122 plant name = Dinuba Energy

# %%
# elev_df = pd.read_csv(os.path.join(TEdir,'elev_comp.csv'))
TE_df.head()
# Out:
#    EIA_PLANT_     PLANT_NAME  COUNTY STATE           NAME_OF_WA   LATITUDE  \
# 0           3          Barry  Mobile    AL         Mobile River  31.006964
# 1           7        Gadsden  Etowah    AL          Coosa River  34.013611
# 2           8         Gorgas  Walker    AL        Warrior River  33.644694
# 3          10  Greene County  Greene    AL  Black Warrior River  32.601935
# 4          26     E C Gaston  Shelby    AL          Coosa River  33.244058
#
#    LONGITUDE       COMID          COOLING_TY GENERATION  ... WATER_TYPE  \
# 0 -88.010900  18520855.0             COMPLEX    COMPLEX  ...         FR
# 1 -85.970278  22199835.0  ONCE-THROUGH FRESH  GAS STEAM  ...         FR
# 2 -87.199743  18591860.0  ONCE-THROUGH FRESH       COAL  ...         FR
# 3 -87.782006  18211194.0  ONCE-THROUGH FRESH       COAL  ...         FR
# 4 -86.457463  22273418.0             COMPLEX       COAL  ...         FR
#
#   WITHDRAWAL  CONSUMPTIO  MIN_WITHDR  MAX_WITHDR  MIN_CONSUM  MAX_CONSUM  \
# 0      412.0        7.93       189.0      2990.0        6.54        9.13
# 1       24.4        0.26        11.1       181.0        0.20        0.32
# 2      382.0        4.02       174.0      2830.0        3.14        4.91
# 3      195.0        2.18        89.1      1430.0        1.70        2.66
# 4      142.0        7.56        66.2       997.0        6.51        8.23
#
#    NET_GENERA why_no_CID                                geometry
# 0  11,387,562       None        POINT (-88.01089992 31.00696404)
# 1     214,655       None        POINT (-85.97027778 34.01361111)
# 2   4,652,042       None        POINT (-87.19974286 33.64469388)
# 3   2,207,648       None        POINT (-87.78200563 32.60193544)
# 4   6,578,669       None  POINT (-86.45746253999999 33.24405797)
#
# [5 rows x 21 columns]

# %%
#merge to dataframes on EIA_PLANT_ID
# not necessary if pulling in csv
elev_df = pd.merge(plants_df, elev_phys_mod, on = 'EIA_PLANT_ID')
elev_df = pd.merge(elev_df, TE_df, left_on ='EIA_PLANT_ID', right_on = 'EIA_PLANT_')

# %%
len(elev_df)
# Out:
# 1106

# %%
elev_df = elev_df[['EIA_PLANT_ID', 'PLANT_NAME_x','LATITUDE', 'LONGITUDE','ELEVATION_MTR', 'elevation']]

# %%
#rename columns
cols = ['EIA_PLANT_ID', 'PLANT_NAME','LATITUDE', 'LONGITUDE', 'ELEV_phys_mod', 'ELEV_gm']
elev_df.columns = cols
elev_df['PM-gM'] =  elev_df['ELEV_phys_mod'] - elev_df['ELEV_gm']

#

# %%
elev_df.to_csv('elev_df_interp.csv')

# %%
#turn it into a pandas geodataframe for plotting
geometry = [Point(xy) for xy in zip(elev_df['LONGITUDE'],elev_df['LATITUDE'])]
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x20748485160>,
#  <shapely.geometry.point.Point at 0x20748485048>,
#  <shapely.geometry.point.Point at 0x207484852b0>]

# %%
crs = {'init': 'epsg:4326'}
elev_df_gd = gpd.GeoDataFrame(elev_df, crs = crs, geometry= geometry)

# %%
lst_of_large_elev_diffs = elev_df_gd[np.absolute(elev_df_gd['PM-gM'])>100]

# %%
lst_of_large_elev_diffs
# Out:
#       EIA_PLANT_ID                       PLANT_NAME   LATITUDE   LONGITUDE  \
# 324           2828                         Cardinal  40.252031  -80.648719
# 332           2866           FirstEnergy W H Sammis  40.531592  -80.631616
# 410           3644                           Carbon  39.727095 -110.864505
# 413           3776                         Glen Lyn  37.369889  -80.863361
# 421           3936                    Kanawha River  38.206438  -81.423525
# 503           6099                    Diablo Canyon  35.210993 -120.855062
# 634           8069                       Huntington  39.379215 -111.079484
# 644          10003  Colorado Energy Nations Company  39.760556 -105.215000
# 684          10495             Rumford Cogeneration  44.551747  -70.541103
# 713          10764              Blue Lake Power LLC  40.877535 -123.994921
# 737          50099      Tamarack Energy Partnership  44.954858 -116.386856
# 746          50279           Archbald Power Station  41.484919  -75.540336
# 781          50776    Panther Creek Energy Facility  40.855381  -75.878258
# 807          50951       Sunnyside Cogen Associates  39.546235 -110.391086
# 972          55393            Metcalf Energy Center  37.220523 -121.745935
# 1070         57028        Langley Gulch Power Plant  43.904444 -116.819722
#
#       ELEV_phys_mod      ELEV_gm       PM-gM  \
# 324        204.5208   313.399994 -108.879194
# 332        208.1784   328.040009 -119.861609
# 410       1865.6808  2090.639893 -224.959093
# 413        473.0496   651.000000 -177.950400
# 421        189.5856   349.239990 -159.654390
# 503          0.0000   200.000000 -200.000000
# 634       1969.0080  2300.600098 -331.592098
# 644       1717.8528  1878.839966 -160.987166
# 684        138.6840   283.239990 -144.555990
# 713         25.2984   281.833344 -256.534944
# 737       1268.5776  1410.000000 -141.422400
# 746        282.8544   425.320007 -142.465607
# 781        325.8312   436.559998 -110.728798
# 807       1979.3712  2150.919922 -171.548722
# 972         74.6760   233.639999 -158.963999
# 1070       870.5088   768.280029  102.228771
#
#                                   geometry
# 324       POINT (-80.64871855 40.25203144)
# 332       POINT (-80.63161563 40.53159188)
# 410       POINT (-110.8645046 39.72709484)
# 413         POINT (-80.863361 37.36988861)
# 421       POINT (-81.42352506 38.20643756)
# 503       POINT (-120.8550621 35.21099282)
# 634        POINT (-111.079484 39.37921497)
# 644           POINT (-105.215 39.76055556)
# 684   POINT (-70.54110300000001 44.551747)
# 713       POINT (-123.9949211 40.87753527)
# 737          POINT (-116.386856 44.954858)
# 746           POINT (-75.540336 41.484919)
# 781       POINT (-75.87825798 40.85538138)
# 807        POINT (-110.3910855 39.5462351)
# 972       POINT (-121.7459353 37.22052294)
# 1070         POINT (-116.819722 43.904444)

# %%
lst_of_plants = lst_of_large_elev_diffs.loc[:,'PLANT_NAME']

# %%
# for testing
# lst_of_plants = lst_of_plants[0:2]
# lst_of_large_elev_diffs.iloc[0,2]

# %%
lst_of_plants
# Out:
# 324                            Cardinal
# 332              FirstEnergy W H Sammis
# 410                              Carbon
# 413                            Glen Lyn
# 421                       Kanawha River
# 503                       Diablo Canyon
# 634                          Huntington
# 644     Colorado Energy Nations Company
# 684                Rumford Cogeneration
# 713                 Blue Lake Power LLC
# 737         Tamarack Energy Partnership
# 746              Archbald Power Station
# 781       Panther Creek Energy Facility
# 807          Sunnyside Cogen Associates
# 972               Metcalf Energy Center
# 1070          Langley Gulch Power Plant
# Name: PLANT_NAME, dtype: object

# %%
# set up lists for loops- 06/16/2020-- add in precip, specific humidity, surface radiation, wind direction, 
# palmer drought index(*only every 10 days, will explore this more), alfalfa ET, vapor pressure deficit

lst_of_vars = ['rmax/rmax', 'rmin/rmin']

lst_of_dh = ['relative_humidity', 'relative_humidity']

lst_of_vars = ['rmax/rmax', 'rmin/rmin', 'tmmn/tmmn','tmmx/tmmx', 'vs/vs', 'pet/pet', 'pr/pr', 'sph/sph', 'srad/srad',
              'th/th', 'etr/etr', 'vpd/vpd']
lst_of_dh = ['relative_humidity', 'relative_humidity', 'air_temperature', 'air_temperature', 
             'wind_speed', 'potential_evapotranspiration', 'precipitation_amount', 'specific_humidity',
            'surface_downwelling_shortwave_flux_in_air', 'wind_from_direction', 'potential_evapotranspiration', 
            'mean_vapor_pressure_deficit']

dirPath='http://thredds.northwestknowledge.net:8080'

# %%
#interp the elevation
#var = 'elev/elev'
dh= 'elevation'
dirPath='http://thredds.northwestknowledge.net:8080'

fileName = '/thredds/dodsC/MET/elev/metdata_elevationdata.nc'
fullfilename= dirPath+fileName
print(fullfilename)
ds = xr.open_dataset(fullfilename)
print(ds, flush =True)

lathandle=ds['lat']
lonhandle=ds['lon']
timehandle=ds['day']
datahandle = ds[dh]
#crshandle=ds['crs']
ts = datahandle.sizes
print(type(ts), flush=True)
print(ts['day'], flush=True)
dayshape = ts['day']
Lonshape = ts['lon']
Latshape = ts['lat']

for i, plant in enumerate(lst_of_plants):
    var = (ds[dh])
    var1 = var.interp(lat =lst_of_large_elev_diffs.iloc[i,2] , lon = lst_of_large_elev_diffs.iloc[i,3])
    var_df = xr.DataArray.to_dataframe(var1)
    var_df = var_df.drop(['lat', 'lon'], axis = 1)   
    
    
    var_df['PLANT_NAME'] = plant 
    var_df['EIA_PLANT_ID'] = lst_of_large_elev_diffs.iloc[i,0]  
    
    if i == 0:
        plants_df = var_df.copy(deep=True)
    else:
        plants_df = plants_df.append(var_df)
        
    print("plant # " + str(i) + " out of 1122 " + "plant name = " + plant)
# Out:
# http://thredds.northwestknowledge.net:8080/thredds/dodsC/MET/elev/metdata_elevationdata.nc
# <xarray.Dataset>
# Dimensions:    (day: 1, lat: 585, lon: 1386)
# Coordinates:
#   * lon        (lon) float32 -124.77216 -124.7305 ... -67.10641 -67.064735
#   * lat        (lat) float32 49.396023 49.354355 49.31269 ... 25.104736 25.06307
#   * day        (day) datetime64[ns] 1900-01-02
# Data variables:
#     elevation  (day, lat, lon) float32 ...
# Attributes:
#     author:   John Abatzoglou - University of Idaho, jabatzoglou@uidaho.edu
#     date:     14 November 2011
#     note1:    The projection information for this file is: GCS WGS 1984.
#     note2:    Citation: Abatzoglou, J.T., 2012, Development of gridded surfac...
# <class 'xarray.core.utils.Frozen'>
# 1
# plant # 0 out of 1122 plant name = Cardinal
# plant # 1 out of 1122 plant name = FirstEnergy W H Sammis
# plant # 2 out of 1122 plant name = Carbon
# plant # 3 out of 1122 plant name = Glen Lyn
# plant # 4 out of 1122 plant name = Kanawha River
# plant # 5 out of 1122 plant name = Diablo Canyon
# plant # 6 out of 1122 plant name = Huntington
# plant # 7 out of 1122 plant name = Colorado Energy Nations Company
# plant # 8 out of 1122 plant name = Rumford Cogeneration
# plant # 9 out of 1122 plant name = Blue Lake Power LLC
# plant # 10 out of 1122 plant name = Tamarack Energy Partnership
# plant # 11 out of 1122 plant name = Archbald Power Station
# plant # 12 out of 1122 plant name = Panther Creek Energy Facility
# plant # 13 out of 1122 plant name = Sunnyside Cogen Associates
# plant # 14 out of 1122 plant name = Metcalf Energy Center
# plant # 15 out of 1122 plant name = Langley Gulch Power Plant

# %%
plants_df
# Out:
#               elevation                       PLANT_NAME  EIA_PLANT_ID
# day
# 1900-01-02   298.188132                         Cardinal          2828
# 1900-01-02   309.583526           FirstEnergy W H Sammis          2866
# 1900-01-02  2110.179251                           Carbon          3644
# 1900-01-02   620.444211                         Glen Lyn          3776
# 1900-01-02   337.521371                    Kanawha River          3936
# 1900-01-02   116.803354                    Diablo Canyon          6099
# 1900-01-02  2236.976752                       Huntington          8069
# 1900-01-02  1865.329472  Colorado Energy Nations Company         10003
# 1900-01-02   246.479587             Rumford Cogeneration         10495
# 1900-01-02   176.429248              Blue Lake Power LLC         10764
# 1900-01-02  1369.288551      Tamarack Energy Partnership         50099
# 1900-01-02   374.758772           Archbald Power Station         50279
# 1900-01-02   414.009293    Panther Creek Energy Facility         50776
# 1900-01-02  2074.979662       Sunnyside Cogen Associates         50951
# 1900-01-02   167.855225            Metcalf Energy Center         55393
# 1900-01-02   760.583486        Langley Gulch Power Plant         57028

# %%
# Step 2- Pull the data from gridMET using two loops-  one for variables and one for plants, this takes some time. 
# output csv with data is TE_plants_w_2015_daily_gridMET.csv if you dont want to run this loop
# Pull data from Northwest Knowledge Network. ds is an xarray

for i, val in enumerate(lst_of_vars):
    fileName = '/thredds/dodsC/MET/' + val + '_2015.nc'
    fullfilename= dirPath+fileName
    print(fullfilename)
    fullfilename= dirPath+fileName
    ds = xr.open_dataset(fullfilename)
    print(ds, flush =True)
    lathandle=ds['lat']
    lonhandle=ds['lon']
    timehandle=ds['day']
    datahandle = ds[lst_of_dh[i]]
    crshandle=ds['crs']
    ts = datahandle.sizes
    print(type(ts), flush=True)
    print(ts['day'], flush=True)
    dayshape = ts['day']
    Lonshape = ts['lon']
    Latshape = ts['lat']
    var = (ds[lst_of_dh[i]])
    
    for j, plant in enumerate(lst_of_plants):
        var1 = var.interp(lat =lst_of_large_elev_diffs.iloc[j,2] , lon = lst_of_large_elev_diffs.iloc[j,3])
        var_df1 = xr.DataArray.to_dataframe(var1)
        var_df1 = var_df1.drop(['lat', 'lon'], axis = 1)
        var_df1['PLANT_NAME'] = plant 
        var_df1['EIA_PLANT_'] = lst_of_large_elev_diffs.iloc[j,0] 
        if j == 0:
            plants_df = var_df1.copy(deep=True)
        else:
            plants_df = plants_df.append(var_df1)
            
    plants_df.reset_index(inplace=True)
    plants_df['EIA_P_DATE'] = plants_df['EIA_PLANT_'].astype(str) + "_" + plants_df['day'].astype(str)
    plants_df.rename({lst_of_dh[i]: val}, axis =1, inplace = True)

    if i == 0:
        final_df = plants_df.copy(deep=True)
    else:
        final_df = final_df.merge(plants_df, left_on = 'EIA_P_DATE', right_on = 'EIA_P_DATE', sort = True)
        
    print("var " + str(i) + " out of 11 variables," + "=" + val)
# Out:
# http://thredds.northwestknowledge.net:8080/thredds/dodsC/MET/rmax/rmax_2015.nc
# <xarray.Dataset>
# Dimensions:            (crs: 1, day: 365, lat: 585, lon: 1386)
# Coordinates:
#   * lat                (lat) float64 49.4 49.36 49.32 ... 25.15 25.11 25.07
#   * lon                (lon) float64 -124.8 -124.7 -124.7 ... -67.1 -67.06
#   * crs                (crs) float32 3.0
#   * day                (day) datetime64[ns] 2015-01-01 2015-01-02 ... 2015-12-31
# Data variables:
#     relative_humidity  (day, lat, lon) float32 ...
# Attributes:
#     geospatial_bounds_crs:      EPSG:4326
#     Conventions:                CF-1.6
#     geospatial_bounds:          POLYGON((-124.7666666333333 49.40000000000000...
#     geospatial_lat_min:         25.066666666666666
#     geospatial_lat_max:         49.40000000000000
#     geospatial_lon_min:         -124.7666666333333
#     geospatial_lon_max:         -67.058333300000015
#     geospatial_lon_resolution:  0.041666666666666
#     geospatial_lat_resolution:  0.041666666666666
#     geospatial_lat_units:       decimal_degrees north
#     geospatial_lon_units:       decimal_degrees east
#     coordinate_system:          EPSG:4326
#     author:                     John Abatzoglou - University of Idaho, jabatz...
#     date:                       04 July 2019
#     note1:                      The projection information for this file is: ...
#     note2:                      Citation: Abatzoglou, J.T., 2013, Development...
#     note3:                      Data in slices after last_permanent_slice (1-...
#     note4:                      Data in slices after last_provisional_slice (...
#     note5:                      Days correspond approximately to calendar day...
# <class 'xarray.core.utils.Frozen'>
# 365
# var 0 out of 11 variables,=rmax/rmax
# http://thredds.northwestknowledge.net:8080/thredds/dodsC/MET/rmin/rmin_2015.nc
# <xarray.Dataset>
# Dimensions:            (crs: 1, day: 365, lat: 585, lon: 1386)
# Coordinates:
#   * lat                (lat) float64 49.4 49.36 49.32 ... 25.15 25.11 25.07
#   * lon                (lon) float64 -124.8 -124.7 -124.7 ... -67.1 -67.06
#   * crs                (crs) float32 3.0
#   * day                (day) datetime64[ns] 2015-01-01 2015-01-02 ... 2015-12-31
# Data variables:
#     relative_humidity  (day, lat, lon) float32 ...
# Attributes:
#     geospatial_bounds_crs:      EPSG:4326
#     Conventions:                CF-1.6
#     geospatial_bounds:          POLYGON((-124.7666666333333 49.40000000000000...
#     geospatial_lat_min:         25.066666666666666
#     geospatial_lat_max:         49.40000000000000
#     geospatial_lon_min:         -124.7666666333333
#     geospatial_lon_max:         -67.058333300000015
#     geospatial_lon_resolution:  0.041666666666666
#     geospatial_lat_resolution:  0.041666666666666
#     geospatial_lat_units:       decimal_degrees north
#     geospatial_lon_units:       decimal_degrees east
#     coordinate_system:          EPSG:4326
#     author:                     John Abatzoglou - University of Idaho, jabatz...
#     date:                       04 July 2019
#     note1:                      The projection information for this file is: ...
#     note2:                      Citation: Abatzoglou, J.T., 2013, Development...
#     note3:                      Data in slices after last_permanent_slice (1-...
#     note4:                      Data in slices after last_provisional_slice (...
#     note5:                      Days correspond approximately to calendar day...
# <class 'xarray.core.utils.Frozen'>
# 365
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-5ab9e9d2a9ba> in <module>
#      24
#      25     for j, plant in enumerate(lst_of_plants):
# ---> 26         var1 = var.interp(lat =lst_of_large_elev_diffs.iloc[j,2] , lon = lst_of_large_elev_diffs.iloc[j,3])
#      27         var_df1 = xr.DataArray.to_dataframe(var1)
#      28         var_df1 = var_df1.drop(['lat', 'lon'], axis = 1)
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\dataarray.py in interp(self, coords, method, assume_sorted, kwargs, **coords_kwargs)
#    1029         ds = self._to_temp_dataset().interp(
#    1030             coords, method=method, kwargs=kwargs, assume_sorted=assume_sorted,
# -> 1031             **coords_kwargs)
#    1032         return self._from_temp_dataset(ds)
#    1033
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\dataset.py in interp(self, coords, method, assume_sorted, kwargs, **coords_kwargs)
#    2084         indexers = OrderedDict(self._validate_indexers(coords))
#    2085
# -> 2086         obj = self if assume_sorted else self.sortby([k for k in coords])
#    2087
#    2088         def maybe_variable(obj, k):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\dataset.py in sortby(self, variables, ascending)
#    3887         variables = [v if isinstance(v, DataArray) else self[v]
#    3888                      for v in variables]
# -> 3889         aligned_vars = align(self, *variables, join='left')
#    3890         aligned_self = aligned_vars[0]
#    3891         aligned_other_vars = aligned_vars[1:]
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\alignment.py in align(*objects, **kwargs)
#     161         if not valid_indexers:
#     162             # fast path for no reindexing necessary
# --> 163             new_obj = obj.copy(deep=copy)
#     164         else:
#     165             new_obj = obj.reindex(copy=copy, **valid_indexers)
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\dataset.py in copy(self, deep, data)
#     895         if data is None:
#     896             variables = OrderedDict((k, v.copy(deep=deep))
# --> 897                                     for k, v in self._variables.items())
#     898         elif not utils.is_dict_like(data):
#     899             raise ValueError('Data must be dict-like')
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\dataset.py in <genexpr>(.0)
#     895         if data is None:
#     896             variables = OrderedDict((k, v.copy(deep=deep))
# --> 897                                     for k, v in self._variables.items())
#     898         elif not utils.is_dict_like(data):
#     899             raise ValueError('Data must be dict-like')
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\variable.py in copy(self, deep, data)
#     810                 elif not isinstance(data, PandasIndexAdapter):
#     811                     # pandas.Index is immutable
# --> 812                     data = np.array(data)
#     813         else:
#     814             data = as_compatible_data(data)
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     624
#     625     def __array__(self, dtype=None):
# --> 626         self._ensure_cached()
#     627         return np.asarray(self.array, dtype=dtype)
#     628
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\indexing.py in _ensure_cached(self)
#     621     def _ensure_cached(self):
#     622         if not isinstance(self.array, NumpyIndexingAdapter):
# --> 623             self.array = NumpyIndexingAdapter(np.asarray(self.array))
#     624
#     625     def __array__(self, dtype=None):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     602
#     603     def __array__(self, dtype=None):
# --> 604         return np.asarray(self.array, dtype=dtype)
#     605
#     606     def __getitem__(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     508     def __array__(self, dtype=None):
#     509         array = as_indexable(self.array)
# --> 510         return np.asarray(array[self.key], dtype=None)
#     511
#     512     def transpose(self, order):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\coding\variables.py in __array__(self, dtype)
#      66
#      67     def __array__(self, dtype=None):
# ---> 68         return self.func(self.array)
#      69
#      70     def __repr__(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\coding\variables.py in _scale_offset_decoding(data, scale_factor, add_offset, dtype)
#     182
#     183 def _scale_offset_decoding(data, scale_factor, add_offset, dtype):
# --> 184     data = np.array(data, dtype=dtype, copy=True)
#     185     if scale_factor is not None:
#     186         data *= scale_factor
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\coding\variables.py in __array__(self, dtype)
#      66
#      67     def __array__(self, dtype=None):
# ---> 68         return self.func(self.array)
#      69
#      70     def __repr__(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\coding\variables.py in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     133 ) -> np.ndarray:
#     134     """Mask all matching values in a NumPy arrays."""
# --> 135     data = np.asarray(data, dtype=dtype)
#     136     condition = False
#     137     for fv in encoded_fill_values:
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\coding\variables.py in __array__(self, dtype)
#      66
#      67     def __array__(self, dtype=None):
# ---> 68         return self.func(self.array)
#      69
#      70     def __repr__(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\indexing.py in __array__(self, dtype)
#     508     def __array__(self, dtype=None):
#     509         array = as_indexable(self.array)
# --> 510         return np.asarray(array[self.key], dtype=None)
#     511
#     512     def transpose(self, order):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\backends\netCDF4_.py in __getitem__(self, key)
#      62         return indexing.explicit_indexing_adapter(
#      63             key, self.shape, indexing.IndexingSupport.OUTER,
# ---> 64             self._getitem)
#      65
#      66     def _getitem(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\core\indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     776     """
#     777     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 778     result = raw_indexing_method(raw_key.tuple)
#     779     if numpy_indices.tuple:
#     780         # index the loaded np.ndarray
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\backends\netCDF4_.py in _getitem(self, key)
#      73             with self.datastore.lock:
#      74                 original_array = self.get_array(needs_lock=False)
# ---> 75                 array = getitem(original_array, key)
#      76         except IndexError:
#      77             # Catch IndexError in netCDF4 and return a more informative
#
# ~\AppData\Local\Continuum\anaconda3\envs\ofp_for_te2\lib\site-packages\xarray\backends\common.py in robust_getitem(array, key, catch, max_retries, initial_delay)
#      53     for n in range(max_retries + 1):
#      54         try:
# ---> 55             return array[key]
#      56         except catch:
#      57             if n == max_retries:
#
# KeyboardInterrupt:

# %%
interp_df = final_df[['EIA_P_DATE', 'rmax/rmax', 
        'rmin/rmin', 'tmmn/tmmn','tmmx/tmmx', 'vs/vs', 'pet/pet', 'pr/pr', 
        'sph/sph', 'srad/srad','th/th', 'etr/etr', 'vpd/vpd']]

# %%
interp_df
# Out:
#             EIA_P_DATE  rmax/rmax  rmin/rmin   tmmn/tmmn   tmmx/tmmx  \
# 0     10003_2010-01-01  72.214398  25.623253  266.523627  281.041603
# 1     10003_2010-01-02  80.618506  32.977495  267.819886  280.749650
# 2     10003_2010-01-03  94.590345  43.870935  264.882613  276.027621
# 3     10003_2010-01-04  72.275784  28.344586  265.793274  278.892271
# 4     10003_2010-01-05  57.603679  23.994828  270.663308  282.992949
# ...                ...        ...        ...         ...         ...
# 5835   8069_2010-12-27  93.719412  47.037551  263.246795  274.092824
# 5836   8069_2010-12-28  91.982017  40.467009  262.170190  274.649414
# 5837   8069_2010-12-29  62.781792  36.669666  263.346801  271.672754
# 5838   8069_2010-12-30  95.315702  68.671312  257.546805  263.316979
# 5839   8069_2010-12-31  68.208213  47.940555  250.424201  265.322697
#
#          vs/vs   pet/pet      pr/pr   sph/sph   srad/srad       th/th  \
# 0     3.224000  1.500000   0.000000  0.002117   92.780695  239.653333
# 1     3.400000  1.408320   0.000000  0.002628   91.232696  251.000000
# 2     2.350347  0.800000   0.000000  0.002484   65.533708  313.386666
# 3     2.524000  1.200000   0.000000  0.002007   95.596374  266.346667
# 4     4.065333  2.024000   0.000000  0.002271   95.015362  245.693333
# ...        ...       ...        ...       ...         ...         ...
# 5835  3.224031  0.799768   0.000000  0.002337   99.552814  298.505796
# 5836  2.600878  0.825322   0.000000  0.002110   92.250828  183.000000
# 5837  6.401341  1.300000  16.441203  0.001542   79.414174  320.501159
# 5838  9.149702  0.399768   0.000000  0.001507   86.812490  305.505796
# 5839  5.850994  0.600000   0.000000  0.001052  101.727374  359.000000
#
#        etr/etr   vpd/vpd
# 0     2.449653  0.441429
# 1     2.216640  0.380997
# 2     1.208320  0.211664
# 3     1.873653  0.369931
# 4     3.297653  0.562997
# ...        ...       ...
# 5835  1.224213  0.177375
# 5836  1.249884  0.207433
# 5837  2.049884  0.229977
# 5838  0.624213  0.044965
# 5839  0.900000  0.084988
#
# [5840 rows x 13 columns]

# %%
# verify WB equation from Stull (2011)

T = 20
RH = 50


a = T*np.arctan(0.151977*np.power((RH + 8.313659),(1/2)))
b = np.arctan(T + RH) - np.arctan(RH - 1.676331)
c = 0.00391838*(np.power(RH,(3/2)))*np.arctan(0.023101*RH) - 4.686035

Tw = a + b + c
Tw
# Out:
# 13.699341968988136

# %%
interp_df.columns
# Out:
# Index(['EIA_P_DATE', 'rh_mx_prcnt', 'rh_mn_prcnt', 'air_tmn_K', 'air_tmx_K',
#        'wnd_spd_m_s', 'ref_et_gr_mm', 'precip_mm', 'sp_h_kg_pr_kg',
#        'sur_rad_Wm2', 'wnd_dir_dg_clk_frm_N', 'ref_et_alf_mm', 'vpdef_kPa'],
#       dtype='object')

# %%
#rename column headers
cols = ['EIA_P_DATE', 'rh_mx_prcnt', 'rh_mn_prcnt', 'air_tmn_K', 'air_tmx_K', 'wnd_spd_m_s',
        'ref_et_gr_mm', 'precip_mm', 'sp_h_kg_pr_kg', 'sur_rad_Wm2','wnd_dir_dg_clk_frm_N',
        'ref_et_alf_mm','vpdef_kPa']
interp_df.columns = cols

# %%
#add means and calculated columns
rh = interp_df.loc[:,'rh_mx_prcnt':'rh_mn_prcnt']
interp_df['rh_avg_prcnt'] = rh.mean(axis = 1)

temp = interp_df.loc[:,'air_tmn_K':'air_tmx_K']
temp = temp.mean(axis = 1)
interp_df['air_tmp_avg_C'] = temp -273.15

#et = plants_df.loc[:,'ref_et_gr_mm']
interp_df['open_wtr_et_mm'] = interp_df['ref_et_gr_mm']*1.05

T = interp_df['air_tmp_avg_C']
RH = interp_df['rh_avg_prcnt']

a = T*np.arctan(0.151977*np.power((RH + 8.313659),(1/2)))
b = np.arctan(T + RH) - np.arctan(RH - 1.676331)
c = 0.00391838*(np.power(RH,(3/2)))*np.arctan(0.023101*RH) - 4.686035

Tw = a + b + c

interp_df['wb_tmp_C'] = Tw


#re_order columns
interp_df = interp_df[['EIA_P_DATE', 'rh_avg_prcnt', 'air_tmp_avg_C', 'open_wtr_et_mm', 
                       'wb_tmp_C', 'rh_mx_prcnt', 'rh_mn_prcnt', 'sp_h_kg_pr_kg','air_tmn_K', 'air_tmx_K', 'precip_mm',
                       'wnd_spd_m_s','wnd_dir_dg_clk_frm_N','ref_et_gr_mm','ref_et_alf_mm','sur_rad_Wm2','vpdef_kPa']]

#create a minimalist df with only variables for comparison with physics-based model
interp_df_minimalist = interp_df.drop(columns = ['rh_mx_prcnt', 'rh_mn_prcnt', 'rh_avg_prcnt','air_tmn_K', 'air_tmx_K',
                                                 'sp_h_kg_pr_kg','precip_mm','wnd_dir_dg_clk_frm_N','ref_et_gr_mm',
                                                 'ref_et_alf_mm','sur_rad_Wm2','vpdef_kPa'])

#output as a csv 
interp_df_minimalist.to_csv('interp_TE_plants_w_2010_daily_gridMET.csv')
interp_df.to_csv('interp_TE_plants_w_2010_daily_gridMET_including_processing_variables.csv')

# %%
#combine interp_df and final_df

# %%
with PdfPages('elev_compare.pdf') as pdf:
    fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (8,8))
#    mn = np.min(elev_df_gd['RMSE'])
#    mx = np.max(elev_df_gd['RMSE'])
    ax1.set_title('physMod - gridMET')
    elev_df_gd.plot(ax = ax1, legend = True, column = 'PM-gM', cmap = 'gist_rainbow')
    
    ax2.set_title('hist_gridMET - physMod')
    ax2.hist(elev_df_gd['PM-gM'])
    
    #fig.colorbar(cm.ScalarMappable(cmap = 'gist_rainbow'))
    pdf.savefig()
#    plt.clf()

# %%
with PdfPages('elev_compare_greater_than_mean.pdf') as pdf:
    fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (8,8))
#    mn = np.min(elev_df_gd['RMSE'])
#    mx = np.max(elev_df_gd['RMSE'])
    ax1.set_title('gridMET - physMod')
    a.plot(ax = ax1, legend = True, column = 'DIFF', cmap = 'gist_rainbow')
    
    ax2.set_title('hist_gridMET - physMod')
    ax2.hist(a['DIFF'])
    
    #fig.colorbar(cm.ScalarMappable(cmap = 'gist_rainbow'))
    pdf.savefig()
#    plt.clf()

# %%
# step 1- pull pdsi and elevation from gridMET
var = 'pdsi/pdsi'
dh= 'palmer_drought_severity_index'
dirPath='http://thredds.northwestknowledge.net:8080'

fileName = '/thredds/dodsC/MET/' + var + '_2015.nc'
fullfilename= dirPath+fileName
print(fullfilename)
ds = xr.open_dataset(fullfilename)
print(ds, flush =True)

lathandle=ds['lat']
lonhandle=ds['lon']
timehandle=ds['day']
datahandle = ds[dh]
crshandle=ds['crs']
ts = datahandle.sizes
print(type(ts), flush=True)
print(ts['day'], flush=True)
dayshape = ts['day']
Lonshape = ts['lon']
Latshape = ts['lat']
pdsi = (ds[dh])

# %%
def mean_in_year_month(da):
    month_cnt_2015 = (da.day.dt.year.to_index() - 2015) *12 + da.day.dt.month.to_index()
    
    return da.assign_coords(year_month = month_cnt_2015).groupby('year_month').mean()

# %%
ds_1 = mean_in_year_month(ds)

#ds_1 = mean_in_year_month(ds)

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %%
ds

# %%
with PdfPages('pdsi2_pdf') as pdf:

# %%
month = ['jan','feb','mar','apr', 'may', 'jun', 'jul', 'aug', 'sept', 'oct', 'nov', 'dec']
#month = 'jan'
for m in range(len(month)):
    if m < 8:
        d_s = '2015-0' + str(m+1) +'-01'
        d_e = '2015-0' + str(m+1) + '-20'
    else: 
        d_s = '2015-' + str(m+1) +'-01'
        d_e = '2015-' + str(m+1) + '-20'        

    pdsi_month = ds.palmer_drought_severity_index.loc[d_s:d_e]
    
    
    with PdfPages('pdsi.pdf') as pdf:
        pdsi_month.mean('day').plot()
        pdf.savefig()
        plt.close()
#jan  = ds.palmer_drought_severity_index.loc['2015-01-01':'2015-01-20']

# %%
val

# %%
feb = ds.palmer_drought_severity_index.loc['2015-02-01':'2015-02-20']

# %%
feb.mean('day').plot()

# %%
#is the elevation of the grid cell much different than the elevation of the TE plant location?

# %%
#get list of plants and change 'NTC/MCRD' name for loop to get data at each point
lst_of_plants = TE_df.loc[:,'PLANT_NAME']
lst_of_plants.update(pd.Series(['NTC_MCRD_Energy_Facility'], index =[737]))

# %%
# for testing purposes since loop of 1122 plants takes a while! Uncomment these if you want to go test something out

lst_of_plants = lst_of_plants[0:5]
lst_of_plants

# %%
# set up lists for loops- 06/16/2020-- add in precip, specific humidity, surface radiation, wind direction, 
# palmer drought index(*only every 10 days, will explore this more), alfalfa ET, vapor pressure deficit

lst_of_vars = ['rmax/rmax', 'rmin/rmin', 'tmmn/tmmn','tmmx/tmmx', 'vs/vs', 'pet/pet', 'pr/pr', 'sph/sph', 'srad/srad',
              'th/th', 'etr/etr', 'vpd/vpd']
lst_of_dh = ['relative_humidity', 'relative_humidity', 'air_temperature', 'air_temperature', 
             'wind_speed', 'potential_evapotranspiration', 'precipitation_amount', 'specific_humidity',
            'surface_downwelling_shortwave_flux_in_air', 'wind_from_direction', 'potential_evapotranspiration', 
            'mean_vapor_pressure_deficit']

dirPath='http://thredds.northwestknowledge.net:8080'

# %%
# Step 2- Pull the data from gridMET using two loops-  one for variables and one for plants, this takes some time. 
# Definitely could be faster/better, can work to make this more efficient, but for now here it is.
# On my computer it takes about 1 hour. 
# output csv with data is TE_plants_w_2015_daily_gridMET.csv if you dont want to run this loop

# Pull data from Northwest Knowledge Network. ds is an xarray

for i, plant in enumerate(lst_of_plants):
    for j, val in enumerate(lst_of_vars):
        fileName = '/thredds/dodsC/MET/' + val + '_2015.nc'
        fullfilename= dirPath+fileName
        print(fullfilename)
        ds = xr.open_dataset(fullfilename)
        print(ds, flush =True)
        lathandle=ds['lat']
        lonhandle=ds['lon']
        timehandle=ds['day']
        datahandle = ds[lst_of_dh[j]]
        crshandle=ds['crs']
        ts = datahandle.sizes
        print(type(ts), flush=True)
        print(ts['day'], flush=True)
        dayshape = ts['day']
        Lonshape = ts['lon']
        Latshape = ts['lat']
        var = (ds[lst_of_dh[j]])
        var1 = var.sel(lat =TE_df.iloc[i,5] , lon = TE_df.iloc[i,6] , method = 'nearest')
        var_df1 = xr.DataArray.to_dataframe(var1)
        var_df1 = var_df1.drop(['lat', 'lon'], axis = 1)   

        if j == 0:
            var_df = var_df1.copy(deep=True)
        else:
            var_df = var_df.merge(var_df1, left_index = True, right_index = True)
    
    
    var_df['PLANT_NAME'] = plant 
    var_df['EIA_PLANT_'] = TE_df.iloc[i,0]  
    
    if i == 0:
        plants_df = var_df.copy(deep=True)
    else:
        plants_df = plants_df.append(var_df)
        
    print("plant # " + str(i) + " out of 1122 " + "plant name = " + plant)

# %%
plants_df.head()

# %%
# pull the pdsi data as a separate step since data is only avaialble every 10 days
lst_of_vars = ['pdsi/pdsi']
lst_of_dh = ['palmer_drought_severity_index']
dirPath='http://thredds.northwestknowledge.net:8080'

fileName = '/thredds/dodsC/MET/' + lst_of_vars + '_2015.nc'
ds = xr.open_dataset(fullfilename)
ds['']

for i, plant in enumerate(lst_of_plants):
    for j, val in enumerate(lst_of_vars):
        fileName = '/thredds/dodsC/MET/' + val + '_2015.nc'
        fullfilename= dirPath+fileName
        print(fullfilename)
        ds = xr.open_dataset(fullfilename)
        print(ds, flush =True)
        lathandle=ds['lat']
        lonhandle=ds['lon']
        timehandle=ds['day']
        datahandle = ds[lst_of_dh[j]]
        crshandle=ds['crs']
        ts = datahandle.sizes
        print(type(ts), flush=True)
        print(ts['day'], flush=True)
        dayshape = ts['day']
        Lonshape = ts['lon']
        Latshape = ts['lat']
        var = (ds[lst_of_dh[j]])
        var1 = var.sel(lat =TE_df.iloc[i,5] , lon = TE_df.iloc[i,6] , method = 'nearest')
        var_df1 = xr.DataArray.to_dataframe(var1)
        var_df1 = var_df1.drop(['lat', 'lon'], axis = 1)   

        if j == 0:
            var_df = var_df1.copy(deep=True)
        else:
            var_df = var_df.merge(var_df1, left_index = True, right_index = True)
    
    
    var_df['PLANT_NAME'] = plant 
    var_df['EIA_PLANT_'] = TE_df.iloc[i,0]  
    
    if i == 0:
        pdsi_df = var_df.copy(deep=True)
    else:
        pdsi_df = pdsi_df.append(var_df)
        
    print("plant # " + str(i) + " out of 1122 " + "plant name = " + plant)

# %%
pdsi_df.head()

# %%
pdsi_df.reset_index(inplace=True)
pdsi_df['EIA_P_DATE'] = pdsi_df['EIA_PLANT_'].astype(str) + "_" + pdsi_df['day'].astype(str)

# %%
#output pdsi data
pdsi_df.to_csv('pdsi_at_TE.csv')

# %% [markdown]
# ### Data Processing
#
# ### Empirical expression for wet-bulb temperature
# ### Eqn (1) from Stull (2011)
#
# Tw = T * atan[0.151977(RH% + 8.313659)^ (1/2)] + atan(T + RH%) - atan(RH% - 1.676331) + 0.00391838(RH%)^(3/2)* atan(0.023101* RH%) - 4.686035
#
#
# Where
# Tw  = wet bulb temperature (degc)
# T   = air temperature (degc)
# RH% = relative humidity (%)
#
# This equation is valid for relative humidities between 5% and 99% and for air temperatures between -20 deg C and
# 50 deg C, except for situations having both low humidity and cold temperature. Over the valid range, errors in
# wet-bulb temperature range from -1 deg C to + 0.65 deg C, with mean absolute error of less than 0.3 deg C.
#
# ### Are there areas where rel hum is < 5 % ? Are there areas that have low humidity and cold temperatures? Not worried about > 50 deg C

# %%
# verify WB equation from Stull (2011)

T = 20
RH = 50


a = T*np.arctan(0.151977*np.power((RH + 8.313659),(1/2)))
b = np.arctan(T + RH) - np.arctan(RH - 1.676331)
c = 0.00391838*(np.power(RH,(3/2)))*np.arctan(0.023101*RH) - 4.686035

Tw = a + b + c
Tw

# %%
#Step 3 - Manipulate the dataframe
# calculate average rh and air temp from max and min, convert avg temp from Kelvins to C
# calculate wetbulb from air temp (Stull 2011)
# calculate ET from ref_et

#add a column for EIA_PLANT_DATE
plants_df.reset_index(inplace=True)
plants_df['EIA_P_DATE'] = plants_df['EIA_PLANT_'].astype(str) + "_" + plants_df['day'].astype(str)

#rename column headers
cols = ['day', 'rh_max_%', 'rh_min_%', 'air_tmn_K', 'air_tmx_K', 'wnd_spd_m_s','ref_et_gr_mm', 'precip_mm', 'sp_h_kg/kg', 
        'sur_rad_Wm2','wnd_dir_dg_clk_frm_N','ref_et_alf_mm','vpdef_kPa','PLANT_NAME', 'EIA_PLANT_', 'EIA_P_DATE']
plants_df.columns = cols

#add means and calculated columns
rh = plants_df.loc[:,'rh_max_%':'rh_min_%']
plants_df['rh_avg_%'] = rh.mean(axis = 1)

temp = plants_df.loc[:,'air_tmn_K':'air_tmx_K']
temp = temp.mean(axis = 1)
plants_df['air_tmp_C_avg'] = temp -273.15

#et = plants_df.loc[:,'ref_et_gr_mm']
plants_df['open_wtr_et_mm'] = plants_df['ref_et_gr_mm']*1.05

T = plants_df['air_tmp_C_avg']
RH = plants_df['rh_avg_%']

a = T*np.arctan(0.151977*np.power((RH + 8.313659),(1/2)))
b = np.arctan(T + RH) - np.arctan(RH - 1.676331)
c = 0.00391838*(np.power(RH,(3/2)))*np.arctan(0.023101*RH) - 4.686035

Tw = a + b + c

plants_df['wb_tmp_C'] = Tw


#re_order columns
plants_df = plants_df[['day', 'PLANT_NAME', 'EIA_PLANT_', 'EIA_P_DATE', 'rh_avg_%', 'air_tmp_C_avg', 'open_wtr_et_mm', 
                       'wb_tmp_C', 'rh_max_%', 'rh_min_%', 'sp_h_kg/kg','air_tmn_K', 'air_tmx_K', 'precip_mm','wnd_spd_m_s',
                       'wnd_dir_dg_clk_frm_N','ref_et_gr_mm','ref_et_alf_mm','sur_rad_Wm2','vpdef_kPa']]

#create a minimalist df with only variables for comparison with physics-based model
plants_df_minimalist = plants_df.drop(columns = ['rh_max_%', 'rh_min_%', 'rh_avg_%','air_tmn_K', 'air_tmx_K','sp_h_kg/kg','precip_mm',
                                                 'wnd_dir_dg_clk_frm_N','ref_et_gr_mm','ref_et_alf_mm','sur_rad_Wm2',
                                                 'vpdef_kPa'])

#output as a csv 
plants_df_minimalist.to_csv('TE_plants_w_2015_daily_gridMET.csv')
plants_df.to_csv('TE_plants_w_2015_daily_gridMET_including_processing_variables.csv')
